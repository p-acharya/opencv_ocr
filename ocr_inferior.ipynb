# %%
from google.cloud import vision
import io
import glob

# %%
import os.path
os.path.isfile("snippet_test_ocr.png")
# Out:
# True

# %% [markdown]
# OCR

# %%
def detect_text(path):
    """Detects text in the file."""
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)

    response = client.text_detection(
    image=image,
    image_context={"language_hints": ["kn"]},  # Bengali
    )
    texts = response.text_annotations
    print('Texts:')

    for text in texts:
        print('\n"{}"'.format(text.description))

        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in text.bounding_poly.vertices])

        print('bounds: {}'.format(','.join(vertices)))

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(
                response.error.message))

# %%
detect_text("snippet_kn.PNG")
# Out:
# Texts:
#
# "•ಇಡುಕುಗಬ್ಬ idukugabba [idukugobbe] ೧. (lit] in-
# dependent verse [iduku? + kabba].
# ಇಡುಗಾಯಿ idugayi [iquge:jl] n. [rit] coconuts
# broken on a stone before a temple as an offering to
# the deity [idu + kayi].
# "
# bounds: (10,5),(459,5),(459,160),(10,160)
#
# "•ಇಡುಕುಗಬ್ಬ"
# bounds: (10,5),(128,5),(128,34),(10,34)
#
# "idukugabba"
# bounds: (145,5),(239,5),(239,34),(145,34)
#
# "["
# bounds: (250,5),(258,5),(258,34),(250,34)
#
# "idukugobbe"
# bounds: (261,5),(353,5),(353,34),(261,34)
#
# "]"
# bounds: (355,5),(363,5),(363,34),(355,34)
#
# "೧"
# bounds: (367,5),(375,5),(375,34),(367,34)
#
# "."
# bounds: (376,5),(384,5),(384,34),(376,34)
#
# "("
# bounds: (391,5),(399,5),(399,34),(391,34)
#
# "lit"
# bounds: (399,5),(415,5),(415,34),(399,34)
#
# "]"
# bounds: (421,5),(429,5),(429,34),(421,34)
#
# "in"
# bounds: (433,5),(456,5),(456,34),(433,34)
#
# "dependent"
# bounds: (32,38),(116,38),(116,61),(32,61)
#
# "verse"
# bounds: (124,38),(164,38),(164,61),(124,61)
#
# "["
# bounds: (168,38),(174,38),(174,61),(168,61)
#
# "iduku"
# bounds: (175,38),(219,38),(219,61),(175,61)
#
# "?"
# bounds: (224,38),(230,38),(230,61),(224,61)
#
# "+"
# bounds: (239,38),(245,38),(245,61),(239,61)
#
# "kabba"
# bounds: (252,38),(304,38),(304,61),(252,61)
#
# "]"
# bounds: (304,38),(310,38),(310,61),(304,61)
#
# "."
# bounds: (311,38),(317,38),(317,61),(311,61)
#
# "ಇಡುಗಾಯಿ"
# bounds: (28,75),(127,75),(127,104),(28,104)
#
# "idugayi"
# bounds: (142,75),(204,75),(204,104),(142,104)
#
# "["
# bounds: (221,75),(229,75),(229,104),(221,104)
#
# "iquge"
# bounds: (227,75),(270,75),(270,104),(227,104)
#
# ":"
# bounds: (272,75),(280,75),(280,104),(272,104)
#
# "jl"
# bounds: (278,75),(289,75),(289,104),(278,104)
#
# "]"
# bounds: (290,75),(298,75),(298,104),(290,104)
#
# "n"
# bounds: (305,75),(313,75),(313,104),(305,104)
#
# "."
# bounds: (314,75),(322,75),(322,104),(314,104)
#
# "["
# bounds: (335,75),(343,75),(343,104),(335,104)
#
# "rit"
# bounds: (346,75),(362,75),(362,104),(346,104)
#
# "]"
# bounds: (366,75),(374,75),(374,104),(366,104)
#
# "coconuts"
# bounds: (385,75),(459,75),(459,104),(385,104)
#
# "broken"
# bounds: (31,108),(87,108),(87,131),(31,131)
#
# "on"
# bounds: (96,108),(113,108),(113,131),(96,131)
#
# "a"
# bounds: (123,108),(129,108),(129,131),(123,131)
#
# "stone"
# bounds: (138,108),(178,108),(178,131),(138,131)
#
# "before"
# bounds: (187,108),(238,108),(238,131),(187,131)
#
# "a"
# bounds: (245,108),(251,108),(251,131),(245,131)
#
# "temple"
# bounds: (260,108),(314,108),(314,131),(260,131)
#
# "as"
# bounds: (325,108),(338,108),(338,131),(325,131)
#
# "an"
# bounds: (346,108),(363,108),(363,131),(346,131)
#
# "offering"
# bounds: (373,108),(435,108),(435,131),(373,131)
#
# "to"
# bounds: (443,108),(455,108),(455,131),(443,131)
#
# "the"
# bounds: (30,135),(56,135),(56,160),(30,160)
#
# "deity"
# bounds: (65,135),(99,135),(99,160),(65,160)
#
# "["
# bounds: (106,135),(112,135),(112,160),(106,160)
#
# "idu"
# bounds: (114,135),(139,135),(139,160),(114,160)
#
# "+"
# bounds: (158,135),(164,135),(164,160),(158,160)
#
# "kayi"
# bounds: (173,135),(205,135),(205,160),(173,160)
#
# "]"
# bounds: (205,135),(211,135),(211,160),(205,160)
#
# "."
# bounds: (212,135),(218,135),(218,160),(212,160)

# %%
detect_text("dasdsa.png")
# Out:
# Texts:
#
# "1
# ಇತಿಹಾಸ
# • ಇಡು ” idu [iqu] W. (attack] to hit, to beat (FbSST) ಇಡ್ಡಲಿ iddali [k<ili] ಇಕ್ಷಲಿ, ಇಡ್ಡಲಿಗೆ, ಇಡ್ಲಿ. [chok]
# [Ka. D443].
# idli, an eatable prepared by mixing rice daugh with
# ಇಡುಕ iduka [idikm] A. [woutle] | NALITCWINESS,
# blackgram paste and by steaming it, after getting it
# closeness, straitness 2 Christinction, tightness [Ka.
# femmented, ಐn a prefeated a DMCTCHIS plate with pits
# D445] (L. (Kit.) [ ಪುಟಕು.
# [Ka. D455].
# ಇಡಲಿಕಟ್ಟಿ iddalitatte [idilitatte] , [utensil] Tಡund
# ಇಡುಕು iduku [idhku] ೫. [attack] tc pinch, to
# plate with slight depressions, of about an inch, which
# tweak (Kià.) [Ka. D444].
# are filled in by nice dough and kept inside avessel for
# ಇಡುಕುತಿ iduku [ilku] ಈ ಟಕು, ಇಡುಗು | V. Stearning (iddali + tuutte]-
# [contain] to pack & 5KMTothing (intದ SuitCHSC, etc.), ಆಡ ಳಿಗೆ iddalige (iddegalige] , [[cookT [Ka. D455]
# to stuff (a suitcase, etc.) with * ಸೂಟ್ಸ್ಸಿ ನಲ್ಲಿ ಬಟ್ಟೆಯನ್ನು (M; Kin) ಇಡಲಿ.
# ಇಡಧನು. H (Jacked his clothes in the suitcast, 2 R. ಆಡು, idu [ignu] H. Trouble] | im[edicMent,
# [trouble [ 1 naTOWNESS, Straightness 2 ( fig) tight fix,
# * hindrance, trouble 2 [hate] cnrnity (DEINR) [Ka.
# Predicament, hvcing Caught between two altematives
# D435ು.
# 3 (fig.) Construction, tightness = ಪುಕ್ಕಟ್ಟು (Ka. D445].
# ಇಡ್ಡಿ idli [id]li]. [cook] [Ka. *D455] ಪುಡ್ಡಲಿ.
# •ಇಡುಕುತ iduku [iqulu] vt. [throw] tch throw away
# ಇಡ್ಡಿ ಸ್ಟ್ಯಾಂಡ್ idli styami [idli =
# [Ka].
# s[ad] H. [CTKO&] stand having
# ಇಡುಗಂಟು idugantu [i«quಥrfu] . [nn.) 1 deposit
# plates with myuld for preparing ವಹೈ
# (in a bank, etc.) 2 security IMZNnew depದited for COO-
# idlis [See Fig] [+ Eg. SEEnd].
# testing an electicMI, for bidding, its earnest MOncy,
# ಇಣಕು inaku (inku] ಪುಣಿಕು, T= Idli sand ಇಡ್ಲಿ
# etc. (idu + ganita]-
# ಣುಕು vi. [view] to peep, to lock
# •ಇಡುಕುಗಟ್ಟ idukugabba [i«qukugalbloo] , [[li] in- furtively [Ka?].
# dependent Verse [iduku? + kabba].
# ಇಣಚಿ [uali] . [Imammal]] squirrel [Ka. D2315]=
# ಇಡುಗಾಯಿ idugayi [iquguji] , [nt] CONCnuts ಅಳಿಲು.
# broken on a stione effore ೩ tenurple as an offering thದ ಇಣಿಕು iniku (injku] vi. [[view'T INಪಣಕು.
# the deity (iಘia + kayi].
# ಇಣುಕು inuku [iniku] Vi. [view] [ ಪುಣಕು.
# ಇಡುಗು idugu (idhgu] *1. [puble] 1 naTTOW- Qಇತರ [itaru] (೧fj-) [Comp-1 other, different [Sk.] -
# ness, closeness, straitness 2 ( fig) C©nstriction, tight- ಬೇರೆಯ (col} -
# NCSS 2 Vi, [ful] Iುಡುಕು* Ich be full, to spread qಇತರೇತರ itaretara [itaneztam] adj. [Soc.] IMLI-
# everywhere (as fragrance, SIncl, SIMwake, fame, etc. tual, TecipICKLal – ಮಿತ್ರರು ಇತರೇತರ ಆ ವಾರ ಮಾಡಿದರು.
# in a space) [Ka. D445].
# The friends extended Imutual help. [Sk].
# ಇಡುಗೆ iduge (kly] . [move] 1 [om.] ornament ಇತಿ iti [it] Latv: [manner) adv, 80, thus, there-
# (that has been WDrm) 2 [com] deposit [Ka. D442], fore 1 ... . ಇತಿ ನಿಮ್ಮ ವಿಶ್ವಾಸಿ - nr , slockerely WCurs 2 ..
# [end] end, COInclusion 1 ಈ ಪ್ರಸ್ತಾವಕ್ಕೆ ಪ್ರತಿ ಆಗಿದೆ. This is
# * ಇಡುಪು iduNu [iqu ]. [break] beach, break, hole
# 3finished matter. [Sk]-
# (Kit.) [Ka. 1432].
# =ಇತಿ -iti [iti] Sugf. [gramLY a suffix to forIn fermin-
# •ಇಡುರು iduu [idini] K. [trouble] 1 imprediment,
# ine nuns from ITICuline nouns 1 ಮಡಿವಳ Washerman
# hindranCe 2 trouble 3 [mind) enmity [Ka. 1435].
# frವ ದಿವತಿ WasheraNiMa .
# ಇಡುಎಕೆ iduvike [i«ddy'ke] M. [mದVE] putting, Mp- ಇತಿಮಿತಿ itirmiti [itimiti] , [[end | limit, b•Sunds !
# plying, planting, producing, etc. [Ka D442]. ಅವನ ಆಸೆಗೆ ಇತಿಮಿತಿಯೇ ಇಲ್ಲ. There is no limit at all for his
# •ಇಡುವು iduvu [idduviu] H. [೧nass]] heap, IMALSS (KA, greed. [Sk.]-
# 1440].
# ಇತಿಶ್ರೀ itisrI [it/n] . [end] COnclusion, end, fin-
# •ಇಡ ide [id]n. [lowc] 1 place, sprot, ground 2 space, ish ಅವನ ಕಷ್ಟದ ದಾಳಿಗೆ ಇತಿಶ್ರೀ ಆಯಿತು. His struggling life
# TOOM, Capaciousness or ability tD ACCOImmodate CID- CarThe an end. [Sk].
# tents [Ka. ID434].
# ಇತಿಹಾಸ itihasa [ithy:Sa] . [his.[ history [Sk.].
# "
# bounds: (31,35),(487,35),(487,767),(31,767)
#
# "1"
# bounds: (258,35),(259,35),(259,43),(258,43)
#
# "ಇತಿಹಾಸ"
# bounds: (454,37),(487,37),(487,45),(454,45)
#
# "•"
# bounds: (33,59),(36,59),(36,74),(33,74)
#
# "ಇಡು"
# bounds: (39,59),(63,59),(63,74),(39,74)
#
# "”"
# bounds: (64,59),(67,59),(67,74),(64,74)
#
# "idu"
# bounds: (72,59),(84,59),(84,74),(72,74)
#
# "["
# bounds: (91,59),(94,59),(94,74),(91,74)
#
# "iqu"
# bounds: (95,59),(108,59),(108,74),(95,74)
#
# "]"
# bounds: (108,59),(111,59),(111,74),(108,74)
#
# "W"
# bounds: (117,59),(120,59),(120,74),(117,74)
#
# "."
# bounds: (123,59),(126,59),(126,74),(123,74)
#
# "("
# bounds: (131,59),(134,59),(134,74),(131,74)
#
# "attack"
# bounds: (136,59),(156,59),(156,74),(136,74)
#
# "]"
# bounds: (158,59),(162,59),(162,74),(158,74)
#
# "to"
# bounds: (165,59),(173,59),(173,74),(165,74)
#
# "hit"
# bounds: (178,59),(187,59),(187,74),(178,74)
#
# ","
# bounds: (188,59),(191,59),(191,74),(188,74)
#
# "to"
# bounds: (193,59),(201,59),(201,74),(193,74)
#
# "beat"
# bounds: (207,59),(222,59),(222,74),(207,74)
#
# "("
# bounds: (224,59),(227,59),(227,74),(224,74)
#
# "FbSST"
# bounds: (229,59),(251,59),(251,74),(229,74)
#
# ")"
# bounds: (253,59),(256,59),(256,74),(253,74)
#
# "ಇಡ್ಡಲಿ"
# bounds: (269,59),(300,59),(300,74),(269,74)
#
# "iddali"
# bounds: (303,59),(325,59),(325,74),(303,74)
#
# "["
# bounds: (328,59),(331,59),(331,74),(328,74)
#
# "k"
# bounds: (334,59),(337,59),(337,74),(334,74)
#
# "<"
# bounds: (341,59),(344,59),(344,74),(341,74)
#
# "ili"
# bounds: (348,59),(354,59),(354,74),(348,74)
#
# "]"
# bounds: (357,59),(360,59),(360,74),(357,74)
#
# "ಇಕ್ಷಲಿ"
# bounds: (361,59),(385,59),(385,74),(361,74)
#
# ","
# bounds: (385,59),(388,59),(388,74),(385,74)
#
# "ಇಡ್ಡಲಿಗೆ"
# bounds: (390,59),(420,59),(420,74),(390,74)
#
# ","
# bounds: (421,59),(424,59),(424,74),(421,74)
#
# "ಇಡ್ಲಿ"
# bounds: (427,59),(441,59),(441,74),(427,74)
#
# "."
# bounds: (451,59),(454,59),(454,74),(451,74)
#
# "["
# bounds: (457,59),(460,59),(460,74),(457,74)
#
# "chok"
# bounds: (462,59),(477,59),(477,74),(462,74)
#
# "]"
# bounds: (480,59),(483,59),(483,74),(480,74)
#
# "["
# bounds: (42,76),(44,76),(44,87),(42,87)
#
# "Ka"
# bounds: (45,76),(58,76),(58,87),(45,87)
#
# "."
# bounds: (57,76),(59,76),(59,87),(57,87)
#
# "D443"
# bounds: (65,76),(85,76),(85,87),(65,87)
#
# "]"
# bounds: (86,76),(88,76),(88,87),(86,87)
#
# "."
# bounds: (89,76),(91,76),(91,87),(89,87)
#
# "idli"
# bounds: (272,75),(285,75),(285,86),(272,86)
#
# ","
# bounds: (286,75),(288,75),(288,86),(286,86)
#
# "an"
# bounds: (293,75),(299,75),(299,86),(293,86)
#
# "eatable"
# bounds: (305,75),(332,75),(332,86),(305,86)
#
# "prepared"
# bounds: (338,75),(371,75),(371,86),(338,86)
#
# "by"
# bounds: (375,75),(383,75),(383,86),(375,86)
#
# "mixing"
# bounds: (391,75),(416,75),(416,86),(391,86)
#
# "rice"
# bounds: (421,75),(435,75),(435,86),(421,86)
#
# "daugh"
# bounds: (438,75),(462,75),(462,86),(438,86)
#
# "with"
# bounds: (468,75),(483,75),(483,86),(468,86)
#
# "ಇಡುಕ"
# bounds: (40,94),(69,94),(69,105),(40,105)
#
# "iduka"
# bounds: (76,94),(97,94),(97,106),(76,106)
#
# "["
# bounds: (108,95),(110,95),(110,106),(108,106)
#
# "idikm"
# bounds: (110,95),(131,95),(131,106),(110,106)
#
# "]"
# bounds: (134,95),(136,95),(136,106),(134,106)
#
# "A"
# bounds: (143,95),(145,95),(145,106),(143,106)
#
# "."
# bounds: (147,95),(149,95),(149,106),(147,106)
#
# "["
# bounds: (158,95),(160,95),(160,106),(158,106)
#
# "woutle"
# bounds: (164,95),(187,95),(187,106),(164,106)
#
# "]"
# bounds: (189,95),(191,95),(191,106),(189,106)
#
# "|"
# bounds: (199,96),(201,96),(201,107),(199,107)
#
# "NALITCWINESS"
# bounds: (209,96),(251,96),(251,107),(209,107)
#
# ","
# bounds: (253,96),(255,96),(255,107),(253,107)
#
# "blackgram"
# bounds: (272,90),(314,90),(314,102),(272,102)
#
# "paste"
# bounds: (319,90),(339,90),(339,102),(319,102)
#
# "and"
# bounds: (344,90),(356,90),(356,102),(344,102)
#
# "by"
# bounds: (363,90),(369,90),(369,102),(363,102)
#
# "steaming"
# bounds: (374,90),(409,90),(409,102),(374,102)
#
# "it"
# bounds: (415,90),(418,90),(418,102),(415,102)
#
# ","
# bounds: (421,90),(423,90),(423,102),(421,102)
#
# "after"
# bounds: (428,90),(444,90),(444,102),(428,102)
#
# "getting"
# bounds: (449,90),(475,90),(475,102),(449,102)
#
# "it"
# bounds: (480,90),(483,90),(483,102),(480,102)
#
# "closeness"
# bounds: (43,110),(80,110),(80,121),(43,121)
#
# ","
# bounds: (81,110),(83,110),(83,121),(81,121)
#
# "straitness"
# bounds: (88,110),(124,110),(124,121),(88,121)
#
# "2"
# bounds: (133,110),(135,110),(135,121),(133,121)
#
# "Christinction"
# bounds: (142,110),(187,110),(187,121),(142,121)
#
# ","
# bounds: (189,110),(191,110),(191,121),(189,121)
#
# "tightness"
# bounds: (196,110),(232,110),(232,121),(196,121)
#
# "["
# bounds: (237,110),(239,110),(239,121),(237,121)
#
# "Ka"
# bounds: (242,110),(252,110),(252,121),(242,121)
#
# "."
# bounds: (253,110),(255,110),(255,121),(253,121)
#
# "femmented"
# bounds: (271,107),(312,107),(312,117),(271,117)
#
# ","
# bounds: (314,107),(316,107),(316,117),(314,117)
#
# "ಐn"
# bounds: (320,107),(328,107),(328,117),(320,117)
#
# "a"
# bounds: (334,107),(336,107),(336,117),(334,117)
#
# "prefeated"
# bounds: (342,107),(380,107),(380,117),(342,117)
#
# "a"
# bounds: (386,107),(388,107),(388,117),(386,117)
#
# "DMCTCHIS"
# bounds: (398,107),(423,107),(423,117),(398,117)
#
# "plate"
# bounds: (428,107),(446,107),(446,117),(428,117)
#
# "with"
# bounds: (449,107),(466,107),(466,117),(449,117)
#
# "pits"
# bounds: (472,107),(484,107),(484,117),(472,117)
#
# "D445"
# bounds: (45,126),(62,126),(62,137),(45,137)
#
# "]"
# bounds: (65,126),(67,126),(67,137),(65,137)
#
# "("
# bounds: (71,126),(73,126),(73,137),(71,137)
#
# "L"
# bounds: (74,126),(76,126),(76,137),(74,137)
#
# "."
# bounds: (79,126),(81,126),(81,137),(79,137)
#
# "("
# bounds: (83,126),(85,126),(85,137),(83,137)
#
# "Kit"
# bounds: (86,126),(96,126),(96,137),(86,137)
#
# "."
# bounds: (97,126),(99,126),(99,137),(97,137)
#
# ")"
# bounds: (100,126),(103,126),(103,137),(100,137)
#
# "["
# bounds: (108,126),(110,126),(110,137),(108,137)
#
# "ಪುಟಕು"
# bounds: (125,126),(144,126),(144,137),(125,137)
#
# "."
# bounds: (147,126),(149,126),(149,137),(147,137)
#
# "["
# bounds: (272,120),(275,120),(275,134),(272,134)
#
# "Ka"
# bounds: (275,120),(288,120),(288,134),(275,134)
#
# "."
# bounds: (287,120),(290,120),(290,134),(287,134)
#
# "D455"
# bounds: (293,120),(314,120),(314,134),(293,134)
#
# "]"
# bounds: (316,120),(319,120),(319,134),(316,134)
#
# "."
# bounds: (319,120),(322,120),(322,134),(319,134)
#
# "ಇಡಲಿಕಟ್ಟಿ"
# bounds: (271,137),(313,137),(313,148),(271,148)
#
# "iddalitatte"
# bounds: (319,138),(359,138),(359,149),(319,149)
#
# "["
# bounds: (364,138),(366,138),(366,149),(364,149)
#
# "id"
# bounds: (367,138),(374,138),(374,149),(367,149)
#
# "ilitatte"
# bounds: (383,138),(409,138),(409,149),(383,149)
#
# "]"
# bounds: (410,138),(412,138),(412,149),(410,149)
#
# ","
# bounds: (420,138),(422,138),(422,149),(420,149)
#
# "["
# bounds: (427,139),(429,139),(429,150),(427,150)
#
# "utensil"
# bounds: (432,139),(454,139),(454,150),(432,150)
#
# "]"
# bounds: (456,139),(458,139),(458,150),(456,150)
#
# "Tಡund"
# bounds: (463,139),(485,139),(485,150),(463,150)
#
# "ಇಡುಕು"
# bounds: (39,143),(73,143),(73,158),(39,158)
#
# "iduku"
# bounds: (87,143),(109,143),(109,158),(87,158)
#
# "["
# bounds: (117,143),(120,143),(120,158),(117,158)
#
# "idhku"
# bounds: (122,143),(143,143),(143,158),(122,158)
#
# "]"
# bounds: (144,143),(147,143),(147,158),(144,158)
#
# "೫"
# bounds: (152,143),(155,143),(155,158),(152,158)
#
# "."
# bounds: (160,143),(163,143),(163,158),(160,158)
#
# "["
# bounds: (169,143),(172,143),(172,158),(169,158)
#
# "attack"
# bounds: (175,143),(195,143),(195,158),(175,158)
#
# "]"
# bounds: (198,143),(202,143),(202,158),(198,158)
#
# "tc"
# bounds: (207,143),(212,143),(212,158),(207,158)
#
# "pinch"
# bounds: (219,143),(240,143),(240,158),(219,158)
#
# ","
# bounds: (240,143),(243,143),(243,158),(240,158)
#
# "to"
# bounds: (247,143),(254,143),(254,158),(247,158)
#
# "plate"
# bounds: (274,153),(291,153),(291,164),(274,164)
#
# "with"
# bounds: (296,153),(311,153),(311,164),(296,164)
#
# "slight"
# bounds: (314,153),(337,153),(337,164),(314,164)
#
# "depressions"
# bounds: (340,153),(387,153),(387,164),(340,164)
#
# ","
# bounds: (388,153),(390,153),(390,164),(388,164)
#
# "of"
# bounds: (394,153),(398,153),(398,164),(394,164)
#
# "about"
# bounds: (402,153),(425,153),(425,164),(402,164)
#
# "an"
# bounds: (426,153),(434,153),(434,164),(426,164)
#
# "inch"
# bounds: (438,153),(453,153),(453,164),(438,164)
#
# ","
# bounds: (456,153),(458,153),(458,164),(456,164)
#
# "which"
# bounds: (460,153),(483,153),(483,164),(460,164)
#
# "tweak"
# bounds: (40,160),(65,160),(65,173),(40,173)
#
# "("
# bounds: (67,160),(70,160),(70,173),(67,173)
#
# "Kià"
# bounds: (72,160),(82,160),(82,173),(72,173)
#
# "."
# bounds: (83,160),(86,160),(86,173),(83,173)
#
# ")"
# bounds: (85,160),(88,160),(88,173),(85,173)
#
# "["
# bounds: (94,160),(97,160),(97,173),(94,173)
#
# "Ka"
# bounds: (99,160),(109,160),(109,173),(99,173)
#
# "."
# bounds: (109,160),(112,160),(112,173),(109,173)
#
# "D444"
# bounds: (118,160),(137,160),(137,173),(118,173)
#
# "]"
# bounds: (137,160),(140,160),(140,173),(137,173)
#
# "."
# bounds: (140,160),(143,160),(143,173),(140,173)
#
# "are"
# bounds: (273,167),(284,167),(284,180),(273,180)
#
# "filled"
# bounds: (288,167),(306,167),(306,180),(288,180)
#
# "in"
# bounds: (309,167),(316,167),(316,180),(309,180)
#
# "by"
# bounds: (320,167),(329,167),(329,180),(320,180)
#
# "nice"
# bounds: (333,167),(347,167),(347,180),(333,180)
#
# "dough"
# bounds: (351,167),(373,167),(373,180),(351,180)
#
# "and"
# bounds: (378,167),(390,167),(390,180),(378,180)
#
# "kept"
# bounds: (394,167),(411,167),(411,180),(394,180)
#
# "inside"
# bounds: (413,167),(436,167),(436,180),(413,180)
#
# "avessel"
# bounds: (439,167),(471,167),(471,180),(439,180)
#
# "for"
# bounds: (472,167),(484,167),(484,180),(472,180)
#
# "ಇಡುಕುತಿ"
# bounds: (41,177),(79,178),(79,190),(41,189)
#
# "iduku"
# bounds: (87,178),(111,178),(111,189),(87,189)
#
# "["
# bounds: (122,179),(124,179),(124,190),(122,190)
#
# "ilku"
# bounds: (124,179),(149,180),(149,191),(124,190)
#
# "]"
# bounds: (150,179),(152,179),(152,190),(150,190)
#
# "ಈ"
# bounds: (161,180),(163,180),(163,191),(161,191)
#
# "ಟಕು"
# bounds: (168,180),(186,180),(186,191),(168,191)
#
# ","
# bounds: (187,180),(189,180),(189,191),(187,191)
#
# "ಇಡುಗು"
# bounds: (196,180),(224,181),(224,193),(196,192)
#
# "|"
# bounds: (234,181),(236,181),(236,192),(234,192)
#
# "V"
# bounds: (246,181),(248,181),(248,192),(246,192)
#
# "."
# bounds: (253,181),(255,181),(255,192),(253,192)
#
# "Stearning"
# bounds: (274,181),(309,182),(309,194),(274,193)
#
# "("
# bounds: (312,183),(314,183),(314,194),(312,194)
#
# "iddali"
# bounds: (315,183),(339,183),(339,194),(315,194)
#
# "+"
# bounds: (343,183),(345,183),(345,194),(343,194)
#
# "tuutte"
# bounds: (350,184),(367,184),(367,195),(350,195)
#
# "]"
# bounds: (368,184),(373,184),(373,195),(368,195)
#
# "["
# bounds: (43,192),(45,192),(45,203),(43,203)
#
# "contain"
# bounds: (49,192),(73,192),(73,204),(49,204)
#
# "]"
# bounds: (75,193),(77,193),(77,204),(75,204)
#
# "to"
# bounds: (81,193),(89,193),(89,204),(81,204)
#
# "pack"
# bounds: (93,193),(109,193),(109,204),(93,204)
#
# "&"
# bounds: (115,194),(117,194),(117,205),(115,205)
#
# "5KMTothing"
# bounds: (122,193),(161,194),(161,206),(122,205)
#
# "("
# bounds: (169,195),(171,195),(171,206),(169,206)
#
# "intದ"
# bounds: (172,195),(187,195),(187,206),(172,206)
#
# "SuitCHSC"
# bounds: (198,195),(229,196),(229,208),(198,207)
#
# ","
# bounds: (230,196),(232,196),(232,207),(230,207)
#
# "etc"
# bounds: (237,196),(245,196),(245,207),(237,207)
#
# "."
# bounds: (247,196),(249,196),(249,207),(247,207)
#
# ")"
# bounds: (249,196),(251,196),(251,207),(249,207)
#
# ","
# bounds: (253,196),(255,196),(255,207),(253,207)
#
# "ಆಡ"
# bounds: (271,197),(289,197),(289,208),(271,208)
#
# "ಳಿಗೆ"
# bounds: (292,197),(306,197),(306,208),(292,208)
#
# "iddalige"
# bounds: (312,197),(345,198),(345,210),(312,209)
#
# "("
# bounds: (350,198),(352,198),(352,209),(350,209)
#
# "iddegalige"
# bounds: (355,198),(387,199),(387,211),(355,210)
#
# "]"
# bounds: (387,199),(389,199),(389,210),(387,210)
#
# ","
# bounds: (399,199),(401,199),(401,210),(399,210)
#
# "["
# bounds: (405,199),(407,199),(407,210),(405,210)
#
# "["
# bounds: (408,199),(410,199),(410,210),(408,210)
#
# "cookT"
# bounds: (411,199),(431,199),(431,211),(411,211)
#
# "["
# bounds: (438,200),(440,200),(440,211),(438,211)
#
# "Ka"
# bounds: (441,200),(454,200),(454,211),(441,211)
#
# "."
# bounds: (452,200),(454,200),(454,211),(452,211)
#
# "D455"
# bounds: (462,201),(479,201),(479,212),(462,212)
#
# "]"
# bounds: (482,201),(484,201),(484,212),(482,212)
#
# "to"
# bounds: (43,207),(49,207),(49,218),(43,218)
#
# "stuff"
# bounds: (55,207),(70,207),(70,219),(55,219)
#
# "("
# bounds: (74,208),(76,208),(76,219),(74,219)
#
# "a"
# bounds: (79,208),(81,208),(81,219),(79,219)
#
# "suitcase"
# bounds: (85,208),(117,209),(117,221),(85,220)
#
# ","
# bounds: (117,209),(119,209),(119,220),(117,220)
#
# "etc"
# bounds: (123,209),(133,209),(133,220),(123,220)
#
# "."
# bounds: (134,209),(136,209),(136,220),(134,220)
#
# ")"
# bounds: (137,209),(139,209),(139,220),(137,220)
#
# "with"
# bounds: (145,210),(159,210),(159,221),(145,221)
#
# "*"
# bounds: (164,210),(166,210),(166,221),(164,221)
#
# "ಸೂಟ್ಸ್ಸಿ"
# bounds: (172,210),(185,210),(185,222),(172,222)
#
# "ನಲ್ಲಿ"
# bounds: (202,211),(209,211),(209,222),(202,222)
#
# "ಬಟ್ಟೆಯನ್ನು"
# bounds: (220,211),(253,212),(253,224),(220,223)
#
# "("
# bounds: (272,213),(274,213),(274,224),(272,224)
#
# "M"
# bounds: (277,213),(279,213),(279,224),(277,224)
#
# ";"
# bounds: (283,213),(285,213),(285,224),(283,224)
#
# "Kin"
# bounds: (294,213),(303,213),(303,225),(294,225)
#
# ")"
# bounds: (307,214),(309,214),(309,225),(307,225)
#
# "ಇಡಲಿ"
# bounds: (330,214),(354,215),(354,227),(330,226)
#
# "."
# bounds: (355,215),(357,215),(357,226),(355,226)
#
# "ಇಡಧನು"
# bounds: (43,223),(77,224),(77,235),(43,234)
#
# "."
# bounds: (80,224),(82,224),(82,235),(80,235)
#
# "H"
# bounds: (87,224),(89,224),(89,235),(87,235)
#
# "("
# bounds: (99,224),(101,224),(101,235),(99,235)
#
# "Jacked"
# bounds: (100,224),(123,225),(123,237),(100,236)
#
# "his"
# bounds: (129,225),(136,225),(136,236),(129,236)
#
# "clothes"
# bounds: (142,225),(165,226),(165,238),(142,237)
#
# "in"
# bounds: (170,226),(174,226),(174,237),(170,237)
#
# "the"
# bounds: (182,227),(189,227),(189,238),(182,238)
#
# "suitcast"
# bounds: (194,226),(220,227),(220,239),(194,238)
#
# ","
# bounds: (222,227),(224,227),(224,238),(222,238)
#
# "2"
# bounds: (238,228),(240,228),(240,239),(238,239)
#
# "R"
# bounds: (248,228),(250,228),(250,239),(248,239)
#
# "."
# bounds: (253,228),(255,228),(255,239),(253,239)
#
# "ಆಡು"
# bounds: (270,229),(292,230),(292,241),(270,240)
#
# ","
# bounds: (294,229),(296,229),(296,240),(294,240)
#
# "idu"
# bounds: (304,230),(320,230),(320,241),(304,241)
#
# "["
# bounds: (332,230),(334,230),(334,241),(332,241)
#
# "ignu"
# bounds: (335,230),(351,230),(351,242),(335,242)
#
# "]"
# bounds: (352,231),(354,231),(354,242),(352,242)
#
# "H"
# bounds: (363,231),(365,231),(365,242),(363,242)
#
# "."
# bounds: (368,231),(370,231),(370,242),(368,242)
#
# "Trouble"
# bounds: (381,231),(411,232),(411,244),(381,243)
#
# "]"
# bounds: (413,232),(415,232),(415,243),(413,243)
#
# "|"
# bounds: (426,233),(428,233),(428,244),(426,244)
#
# "im"
# bounds: (433,233),(443,233),(443,244),(433,244)
#
# "["
# bounds: (446,233),(448,233),(448,244),(446,244)
#
# "edicMent"
# bounds: (452,233),(484,234),(484,246),(452,245)
#
# ","
# bounds: (484,234),(486,234),(486,245),(484,245)
#
# "["
# bounds: (42,240),(45,240),(45,253),(42,253)
#
# "trouble"
# bounds: (47,240),(71,240),(71,253),(47,253)
#
# "["
# bounds: (74,240),(77,240),(77,253),(74,253)
#
# "1"
# bounds: (80,240),(83,240),(83,253),(80,253)
#
# "naTOWNESS"
# bounds: (88,240),(133,240),(133,253),(88,253)
#
# ","
# bounds: (133,240),(136,240),(136,253),(133,253)
#
# "Straightness"
# bounds: (139,240),(186,240),(186,253),(139,253)
#
# "2"
# bounds: (190,240),(193,240),(193,253),(190,253)
#
# "("
# bounds: (196,240),(199,240),(199,253),(196,253)
#
# "fig"
# bounds: (202,240),(210,240),(210,253),(202,253)
#
# ")"
# bounds: (214,240),(217,240),(217,253),(214,253)
#
# "tight"
# bounds: (220,240),(240,240),(240,253),(220,253)
#
# "fix"
# bounds: (241,240),(251,240),(251,253),(241,253)
#
# ","
# bounds: (252,240),(255,240),(255,253),(252,253)
#
# "*"
# bounds: (253,246),(255,246),(255,258),(253,258)
#
# "hindrance"
# bounds: (271,246),(311,246),(311,258),(271,258)
#
# ","
# bounds: (313,246),(315,246),(315,258),(313,258)
#
# "trouble"
# bounds: (321,246),(349,246),(349,258),(321,258)
#
# "2"
# bounds: (357,246),(359,246),(359,258),(357,258)
#
# "["
# bounds: (366,246),(369,246),(369,258),(366,258)
#
# "hate"
# bounds: (371,246),(385,246),(385,258),(371,258)
#
# "]"
# bounds: (387,246),(389,246),(389,258),(387,258)
#
# "cnrnity"
# bounds: (400,246),(426,246),(426,258),(400,258)
#
# "("
# bounds: (431,246),(433,246),(433,258),(431,258)
#
# "DEINR"
# bounds: (436,246),(453,246),(453,258),(436,258)
#
# ")"
# bounds: (456,246),(458,246),(458,258),(456,258)
#
# "["
# bounds: (467,246),(469,246),(469,258),(467,258)
#
# "Ka"
# bounds: (472,246),(482,246),(482,258),(472,258)
#
# "."
# bounds: (482,246),(484,246),(484,258),(482,258)
#
# "Predicament"
# bounds: (44,256),(92,256),(92,267),(44,267)
#
# ","
# bounds: (93,256),(95,256),(95,267),(93,267)
#
# "hvcing"
# bounds: (99,256),(120,256),(120,267),(99,267)
#
# "Caught"
# bounds: (124,256),(151,256),(151,267),(124,267)
#
# "between"
# bounds: (153,256),(185,256),(185,267),(153,267)
#
# "two"
# bounds: (190,256),(206,256),(206,267),(190,267)
#
# "altematives"
# bounds: (210,256),(254,256),(254,267),(210,267)
#
# "D435ು"
# bounds: (276,262),(296,263),(296,274),(276,273)
#
# "."
# bounds: (299,263),(301,263),(301,273),(299,273)
#
# "3"
# bounds: (43,270),(46,270),(46,285),(43,285)
#
# "("
# bounds: (49,270),(52,270),(52,285),(49,285)
#
# "fig"
# bounds: (54,270),(64,270),(64,285),(54,285)
#
# "."
# bounds: (64,270),(67,270),(67,285),(64,285)
#
# ")"
# bounds: (66,270),(69,270),(69,285),(66,285)
#
# "Construction"
# bounds: (73,270),(120,270),(120,285),(73,285)
#
# ","
# bounds: (121,270),(124,270),(124,285),(121,285)
#
# "tightness"
# bounds: (127,270),(163,270),(163,285),(127,285)
#
# "="
# bounds: (166,270),(169,270),(169,285),(166,285)
#
# "ಪುಕ್ಕಟ್ಟು"
# bounds: (176,270),(200,270),(200,285),(176,285)
#
# "("
# bounds: (205,270),(208,270),(208,285),(205,285)
#
# "Ka"
# bounds: (209,270),(220,270),(220,285),(209,285)
#
# "."
# bounds: (221,270),(224,270),(224,285),(221,285)
#
# "D445"
# bounds: (229,270),(248,270),(248,285),(229,285)
#
# "]"
# bounds: (248,270),(251,270),(251,285),(248,285)
#
# "."
# bounds: (252,270),(255,270),(255,285),(252,285)
#
# "ಇಡ್ಡಿ"
# bounds: (271,278),(287,278),(287,293),(271,293)
#
# "idli"
# bounds: (295,278),(307,278),(307,293),(295,293)
#
# "["
# bounds: (313,278),(316,278),(316,293),(313,293)
#
# "id"
# bounds: (315,278),(325,278),(325,293),(315,293)
#
# "]"
# bounds: (327,278),(330,278),(330,293),(327,293)
#
# "li"
# bounds: (332,278),(335,278),(335,293),(332,293)
#
# "]"
# bounds: (337,278),(340,278),(340,293),(337,293)
#
# "."
# bounds: (348,278),(351,278),(351,293),(348,293)
#
# "["
# bounds: (353,278),(356,278),(356,293),(353,293)
#
# "cook"
# bounds: (359,278),(375,278),(375,293),(359,293)
#
# "]"
# bounds: (376,278),(380,278),(380,293),(376,293)
#
# "["
# bounds: (383,278),(386,278),(386,293),(383,293)
#
# "Ka"
# bounds: (389,278),(397,278),(397,293),(389,293)
#
# "."
# bounds: (399,278),(402,278),(402,293),(399,293)
#
# "*"
# bounds: (405,278),(408,278),(408,293),(405,293)
#
# "D455"
# bounds: (411,278),(431,278),(431,293),(411,293)
#
# "]"
# bounds: (433,278),(436,278),(436,293),(433,293)
#
# "ಪುಡ್ಡಲಿ"
# bounds: (456,278),(477,278),(477,293),(456,293)
#
# "."
# bounds: (479,278),(482,278),(482,293),(479,293)
#
# "•ಇಡುಕುತ"
# bounds: (31,289),(78,289),(78,302),(31,302)
#
# "iduku"
# bounds: (85,289),(108,289),(108,302),(85,302)
#
# "["
# bounds: (114,289),(117,289),(117,302),(114,302)
#
# "iqulu"
# bounds: (119,289),(138,289),(138,302),(119,302)
#
# "]"
# bounds: (139,289),(142,289),(142,302),(139,302)
#
# "vt"
# bounds: (147,289),(153,289),(153,302),(147,302)
#
# "."
# bounds: (153,289),(156,289),(156,302),(153,302)
#
# "["
# bounds: (161,289),(164,289),(164,302),(161,302)
#
# "throw"
# bounds: (167,289),(183,289),(183,302),(167,302)
#
# "]"
# bounds: (188,289),(191,289),(191,302),(188,302)
#
# "tch"
# bounds: (196,289),(205,289),(205,302),(196,302)
#
# "throw"
# bounds: (207,289),(227,289),(227,302),(207,302)
#
# "away"
# bounds: (235,289),(255,289),(255,302),(235,302)
#
# "ಇಡ್ಡಿ"
# bounds: (271,296),(287,296),(287,311),(271,311)
#
# "ಸ್ಟ್ಯಾಂಡ್"
# bounds: (296,296),(329,296),(329,311),(296,311)
#
# "idli"
# bounds: (337,296),(351,296),(351,311),(337,311)
#
# "styami"
# bounds: (354,296),(384,296),(384,311),(354,311)
#
# "["
# bounds: (391,296),(394,296),(394,311),(391,311)
#
# "idli"
# bounds: (394,296),(410,296),(410,311),(394,311)
#
# "="
# bounds: (442,296),(445,296),(445,311),(442,311)
#
# "["
# bounds: (42,306),(44,306),(44,316),(42,316)
#
# "Ka"
# bounds: (47,306),(58,306),(58,316),(47,316)
#
# "]"
# bounds: (60,306),(62,306),(62,316),(60,316)
#
# "."
# bounds: (63,306),(65,306),(65,316),(63,316)
#
# "s"
# bounds: (272,313),(275,313),(275,326),(272,326)
#
# "["
# bounds: (276,313),(279,313),(279,326),(276,326)
#
# "ad"
# bounds: (277,313),(301,313),(301,326),(277,326)
#
# "]"
# bounds: (298,313),(301,313),(301,326),(298,326)
#
# "H"
# bounds: (308,313),(311,313),(311,326),(308,326)
#
# "."
# bounds: (312,313),(315,313),(315,326),(312,326)
#
# "["
# bounds: (323,313),(326,313),(326,326),(323,326)
#
# "CTKO"
# bounds: (330,313),(339,313),(339,326),(330,326)
#
# "&"
# bounds: (340,313),(343,313),(343,326),(340,326)
#
# "]"
# bounds: (346,313),(349,313),(349,326),(346,326)
#
# "stand"
# bounds: (356,313),(378,313),(378,326),(356,326)
#
# "having"
# bounds: (383,313),(408,313),(408,326),(383,326)
#
# "ಇಡುಗಂಟು"
# bounds: (42,323),(90,323),(90,335),(42,335)
#
# "idugantu"
# bounds: (94,323),(132,323),(132,335),(94,335)
#
# "["
# bounds: (137,323),(139,323),(139,335),(137,335)
#
# "i"
# bounds: (140,323),(142,323),(142,335),(140,335)
#
# "«"
# bounds: (142,323),(144,323),(144,335),(142,335)
#
# "quಥrfu"
# bounds: (145,323),(175,323),(175,335),(145,335)
#
# "]"
# bounds: (176,323),(178,323),(178,335),(176,335)
#
# "."
# bounds: (188,323),(190,323),(190,335),(188,335)
#
# "["
# bounds: (194,323),(197,323),(197,335),(194,335)
#
# "nn"
# bounds: (198,323),(207,323),(207,335),(198,335)
#
# "."
# bounds: (208,323),(210,323),(210,335),(208,335)
#
# ")"
# bounds: (211,323),(213,323),(213,335),(211,335)
#
# "1"
# bounds: (219,323),(221,323),(221,335),(219,335)
#
# "deposit"
# bounds: (226,323),(255,323),(255,335),(226,335)
#
# "plates"
# bounds: (274,328),(295,328),(295,340),(274,340)
#
# "with"
# bounds: (301,328),(316,328),(316,340),(301,340)
#
# "myuld"
# bounds: (325,328),(349,328),(349,340),(325,340)
#
# "for"
# bounds: (354,328),(365,328),(365,340),(354,340)
#
# "preparing"
# bounds: (371,328),(407,328),(407,340),(371,340)
#
# "ವಹೈ"
# bounds: (454,325),(480,324),(480,337),(454,338)
#
# "("
# bounds: (42,338),(44,338),(44,349),(42,349)
#
# "in"
# bounds: (45,338),(51,338),(51,349),(45,349)
#
# "a"
# bounds: (57,338),(59,338),(59,349),(57,349)
#
# "bank"
# bounds: (64,338),(82,338),(82,349),(64,349)
#
# ","
# bounds: (83,338),(85,338),(85,349),(83,349)
#
# "etc"
# bounds: (91,338),(100,338),(100,350),(91,350)
#
# "."
# bounds: (99,339),(101,339),(101,350),(99,350)
#
# ")"
# bounds: (103,339),(105,339),(105,350),(103,350)
#
# "2"
# bounds: (110,339),(112,339),(112,350),(110,350)
#
# "security"
# bounds: (117,339),(147,339),(147,350),(117,350)
#
# "IMZNnew"
# bounds: (152,339),(177,339),(177,350),(152,350)
#
# "depದited"
# bounds: (182,339),(220,339),(220,351),(182,351)
#
# "for"
# bounds: (222,340),(233,340),(233,351),(222,351)
#
# "COO"
# bounds: (238,340),(254,340),(254,351),(238,351)
#
# "idlis"
# bounds: (273,343),(288,343),(288,357),(273,357)
#
# "["
# bounds: (292,343),(295,343),(295,357),(292,357)
#
# "See"
# bounds: (297,343),(308,343),(308,357),(297,357)
#
# "Fig"
# bounds: (313,343),(325,343),(325,357),(313,357)
#
# "]"
# bounds: (328,343),(331,343),(331,357),(328,357)
#
# "["
# bounds: (334,343),(337,343),(337,357),(334,357)
#
# "+"
# bounds: (338,343),(341,343),(341,357),(338,357)
#
# "Eg"
# bounds: (347,343),(357,343),(357,357),(347,357)
#
# "."
# bounds: (358,343),(361,343),(361,357),(358,357)
#
# "SEEnd"
# bounds: (364,343),(385,343),(385,357),(364,357)
#
# "]"
# bounds: (385,343),(388,343),(388,357),(385,357)
#
# "."
# bounds: (389,343),(392,343),(392,357),(389,357)
#
# "testing"
# bounds: (41,354),(69,354),(69,365),(41,365)
#
# "an"
# bounds: (75,354),(81,354),(81,365),(75,365)
#
# "electicMI"
# bounds: (88,354),(117,354),(117,366),(88,366)
#
# ","
# bounds: (120,355),(122,355),(122,366),(120,366)
#
# "for"
# bounds: (127,355),(137,355),(137,366),(127,366)
#
# "bidding"
# bounds: (143,355),(173,355),(173,366),(143,366)
#
# ","
# bounds: (174,355),(176,355),(176,366),(174,366)
#
# "its"
# bounds: (182,355),(188,355),(188,366),(182,366)
#
# "earnest"
# bounds: (194,355),(221,355),(221,367),(194,367)
#
# "MOncy"
# bounds: (228,356),(251,356),(251,367),(228,367)
#
# ","
# bounds: (253,356),(255,356),(255,367),(253,367)
#
# "ಇಣಕು"
# bounds: (272,361),(298,361),(298,372),(272,372)
#
# "inaku"
# bounds: (305,360),(327,360),(327,372),(305,372)
#
# "("
# bounds: (333,360),(335,360),(335,371),(333,371)
#
# "inku"
# bounds: (336,360),(360,360),(360,371),(336,371)
#
# "]"
# bounds: (360,360),(362,360),(362,371),(360,371)
#
# "ಪುಣಿಕು"
# bounds: (367,360),(388,360),(388,371),(367,371)
#
# ","
# bounds: (390,360),(392,360),(392,371),(390,371)
#
# "T"
# bounds: (399,360),(401,360),(401,371),(399,371)
#
# "="
# bounds: (405,360),(407,360),(407,371),(405,371)
#
# "Idli"
# bounds: (427,359),(439,359),(439,370),(427,370)
#
# "sand"
# bounds: (441,359),(459,359),(459,370),(441,370)
#
# "ಇಡ್ಲಿ"
# bounds: (462,359),(477,359),(477,370),(462,370)
#
# "etc"
# bounds: (45,369),(52,369),(52,380),(45,380)
#
# "."
# bounds: (55,369),(57,369),(57,380),(55,380)
#
# "("
# bounds: (60,370),(62,370),(62,381),(60,381)
#
# "idu"
# bounds: (63,370),(77,370),(77,381),(63,381)
#
# "+"
# bounds: (85,370),(87,370),(87,381),(85,381)
#
# "ganita"
# bounds: (92,370),(116,371),(116,383),(92,382)
#
# "]"
# bounds: (117,371),(122,371),(122,382),(117,382)
#
# "ಣುಕು"
# bounds: (275,376),(293,376),(293,387),(275,387)
#
# "vi"
# bounds: (298,376),(304,376),(304,387),(298,387)
#
# "."
# bounds: (305,376),(307,376),(307,387),(305,387)
#
# "["
# bounds: (313,376),(315,376),(315,387),(313,387)
#
# "view"
# bounds: (318,376),(332,376),(332,387),(318,387)
#
# "]"
# bounds: (336,376),(339,376),(339,387),(336,387)
#
# "to"
# bounds: (343,376),(350,376),(350,387),(343,387)
#
# "peep"
# bounds: (353,376),(372,376),(372,387),(353,387)
#
# ","
# bounds: (374,376),(376,376),(376,387),(374,387)
#
# "to"
# bounds: (379,376),(386,376),(386,387),(379,387)
#
# "lock"
# bounds: (391,376),(407,376),(407,387),(391,387)
#
# "•ಇಡುಕುಗಟ್ಟ"
# bounds: (32,387),(91,388),(91,400),(32,399)
#
# "idukugabba"
# bounds: (99,388),(145,388),(145,400),(99,400)
#
# "["
# bounds: (152,388),(154,388),(154,400),(152,400)
#
# "i"
# bounds: (155,388),(157,388),(157,400),(155,400)
#
# "«"
# bounds: (158,388),(160,388),(160,400),(158,400)
#
# "qukugalbloo"
# bounds: (160,388),(201,388),(201,401),(160,401)
#
# "]"
# bounds: (204,389),(206,389),(206,401),(204,401)
#
# ","
# bounds: (215,389),(217,389),(217,401),(215,401)
#
# "["
# bounds: (220,389),(222,389),(222,401),(220,401)
#
# "["
# bounds: (223,389),(225,389),(225,401),(223,401)
#
# "li"
# bounds: (227,389),(229,389),(229,401),(227,401)
#
# "]"
# bounds: (237,389),(239,389),(239,401),(237,401)
#
# "in"
# bounds: (244,389),(251,389),(251,401),(244,401)
#
# "-"
# bounds: (253,389),(255,389),(255,401),(253,401)
#
# "furtively"
# bounds: (272,389),(305,389),(305,402),(272,402)
#
# "["
# bounds: (310,390),(312,390),(312,402),(310,402)
#
# "Ka"
# bounds: (316,390),(324,390),(324,402),(316,402)
#
# "?"
# bounds: (329,390),(331,390),(331,402),(329,402)
#
# "]"
# bounds: (333,390),(335,390),(335,402),(333,402)
#
# "."
# bounds: (336,390),(338,390),(338,402),(336,402)
#
# "dependent"
# bounds: (43,404),(83,404),(83,416),(43,416)
#
# "Verse"
# bounds: (87,404),(107,404),(107,416),(87,416)
#
# "["
# bounds: (110,404),(112,404),(112,416),(110,416)
#
# "iduku"
# bounds: (113,404),(133,404),(133,416),(113,416)
#
# "?"
# bounds: (138,404),(140,404),(140,416),(138,416)
#
# "+"
# bounds: (146,404),(148,404),(148,416),(146,416)
#
# "kabba"
# bounds: (152,404),(177,404),(177,416),(152,416)
#
# "]"
# bounds: (177,404),(179,404),(179,416),(177,416)
#
# "."
# bounds: (181,404),(183,404),(183,416),(181,416)
#
# "ಇಣಚಿ"
# bounds: (271,407),(297,407),(297,420),(271,420)
#
# "["
# bounds: (304,407),(307,407),(307,420),(304,420)
#
# "uali"
# bounds: (308,407),(328,407),(328,420),(308,420)
#
# "]"
# bounds: (327,407),(330,407),(330,420),(327,420)
#
# "."
# bounds: (339,407),(342,407),(342,420),(339,420)
#
# "["
# bounds: (346,407),(349,407),(349,420),(346,420)
#
# "Imammal"
# bounds: (350,407),(382,407),(382,420),(350,420)
#
# "]"
# bounds: (382,407),(385,407),(385,420),(382,420)
#
# "]"
# bounds: (385,407),(388,407),(388,420),(385,420)
#
# "squirrel"
# bounds: (391,407),(420,407),(420,420),(391,420)
#
# "["
# bounds: (424,407),(427,407),(427,420),(424,420)
#
# "Ka"
# bounds: (429,407),(438,407),(438,420),(429,420)
#
# "."
# bounds: (440,407),(443,407),(443,420),(440,420)
#
# "D2315"
# bounds: (450,407),(472,407),(472,420),(450,420)
#
# "]"
# bounds: (473,407),(476,407),(476,420),(473,420)
#
# "="
# bounds: (480,407),(483,407),(483,420),(480,420)
#
# "ಇಡುಗಾಯಿ"
# bounds: (40,423),(90,423),(90,436),(40,436)
#
# "idugayi"
# bounds: (98,423),(128,423),(128,436),(98,436)
#
# "["
# bounds: (136,423),(139,423),(139,436),(136,436)
#
# "iquguji"
# bounds: (140,423),(170,423),(170,436),(140,436)
#
# "]"
# bounds: (171,423),(174,423),(174,436),(171,436)
#
# ","
# bounds: (184,423),(187,423),(187,436),(184,436)
#
# "["
# bounds: (194,423),(197,423),(197,436),(194,436)
#
# "nt"
# bounds: (200,423),(206,423),(206,436),(200,436)
#
# "]"
# bounds: (209,423),(212,423),(212,436),(209,436)
#
# "CONCnuts"
# bounds: (221,423),(254,423),(254,436),(221,436)
#
# "ಅಳಿಲು"
# bounds: (277,423),(297,423),(297,436),(277,436)
#
# "."
# bounds: (296,423),(299,423),(299,436),(296,436)
#
# "broken"
# bounds: (44,437),(70,437),(70,448),(44,448)
#
# "on"
# bounds: (75,437),(83,437),(83,448),(75,448)
#
# "a"
# bounds: (89,437),(91,437),(91,448),(89,448)
#
# "stione"
# bounds: (97,437),(117,437),(117,448),(97,448)
#
# "effore"
# bounds: (123,437),(145,437),(145,449),(123,449)
#
# "೩"
# bounds: (150,438),(152,438),(152,449),(150,449)
#
# "tenurple"
# bounds: (156,438),(183,438),(183,449),(156,449)
#
# "as"
# bounds: (188,438),(196,438),(196,449),(188,449)
#
# "an"
# bounds: (200,438),(208,438),(208,449),(200,449)
#
# "offering"
# bounds: (213,438),(244,438),(244,449),(213,449)
#
# "thದ"
# bounds: (249,438),(254,438),(254,449),(249,449)
#
# "ಇಣಿಕು"
# bounds: (269,438),(298,438),(298,449),(269,449)
#
# "iniku"
# bounds: (306,438),(326,438),(326,449),(306,449)
#
# "("
# bounds: (331,438),(333,438),(333,449),(331,449)
#
# "injku"
# bounds: (334,438),(355,438),(355,450),(334,450)
#
# "]"
# bounds: (356,439),(358,439),(358,450),(356,450)
#
# "vi"
# bounds: (362,439),(368,439),(368,450),(362,450)
#
# "."
# bounds: (369,439),(371,439),(371,450),(369,450)
#
# "["
# bounds: (374,439),(376,439),(376,450),(374,450)
#
# "["
# bounds: (377,439),(379,439),(379,450),(377,450)
#
# "view"
# bounds: (381,439),(394,439),(394,450),(381,450)
#
# "'"
# bounds: (396,439),(398,439),(398,450),(396,450)
#
# "T"
# bounds: (398,439),(400,439),(400,450),(398,450)
#
# "INಪಣಕು"
# bounds: (403,439),(444,439),(444,450),(403,450)
#
# "."
# bounds: (446,439),(448,439),(448,450),(446,450)
#
# "the"
# bounds: (42,454),(54,454),(54,466),(42,466)
#
# "deity"
# bounds: (57,454),(76,454),(76,466),(57,466)
#
# "("
# bounds: (80,454),(82,454),(82,466),(80,466)
#
# "iಘia"
# bounds: (84,454),(95,454),(95,466),(84,466)
#
# "+"
# bounds: (105,454),(107,454),(107,466),(105,466)
#
# "kayi"
# bounds: (111,454),(129,454),(129,466),(111,466)
#
# "]"
# bounds: (129,454),(131,454),(131,466),(129,466)
#
# "."
# bounds: (132,454),(134,454),(134,466),(132,466)
#
# "ಇಣುಕು"
# bounds: (269,456),(305,456),(305,468),(269,468)
#
# "inuku"
# bounds: (310,456),(334,456),(334,468),(310,468)
#
# "["
# bounds: (338,456),(340,456),(340,468),(338,468)
#
# "iniku"
# bounds: (341,456),(362,456),(362,468),(341,468)
#
# "]"
# bounds: (363,456),(365,456),(365,468),(363,468)
#
# "Vi"
# bounds: (369,456),(377,456),(377,468),(369,468)
#
# "."
# bounds: (377,456),(379,456),(379,468),(377,468)
#
# "["
# bounds: (384,456),(386,456),(386,468),(384,468)
#
# "view"
# bounds: (389,456),(401,456),(401,468),(389,468)
#
# "]"
# bounds: (406,456),(408,456),(408,468),(406,468)
#
# "["
# bounds: (412,456),(414,456),(414,468),(412,468)
#
# "ಪುಣಕು"
# bounds: (431,456),(452,456),(452,468),(431,468)
#
# "."
# bounds: (452,456),(454,456),(454,468),(452,468)
#
# "ಇಡುಗು"
# bounds: (40,472),(74,472),(74,485),(40,485)
#
# "idugu"
# bounds: (81,472),(103,472),(103,485),(81,485)
#
# "("
# bounds: (110,472),(113,472),(113,485),(110,485)
#
# "idhgu"
# bounds: (114,472),(136,472),(136,485),(114,485)
#
# "]"
# bounds: (137,472),(140,472),(140,485),(137,485)
#
# "*"
# bounds: (143,472),(146,472),(146,485),(143,485)
#
# "1"
# bounds: (152,472),(155,472),(155,485),(152,485)
#
# "."
# bounds: (167,472),(170,472),(170,485),(167,485)
#
# "["
# bounds: (175,472),(178,472),(178,485),(175,485)
#
# "puble"
# bounds: (187,472),(205,472),(205,485),(187,485)
#
# "]"
# bounds: (206,472),(209,472),(209,485),(206,485)
#
# "1"
# bounds: (215,472),(218,472),(218,485),(215,485)
#
# "naTTOW"
# bounds: (223,472),(248,472),(248,485),(223,485)
#
# "-"
# bounds: (251,472),(254,472),(254,485),(251,485)
#
# "Qಇತರ"
# bounds: (262,472),(291,472),(291,485),(262,485)
#
# "["
# bounds: (300,472),(303,472),(303,485),(300,485)
#
# "itaru"
# bounds: (303,472),(321,472),(321,485),(303,485)
#
# "]"
# bounds: (322,472),(325,472),(325,485),(322,485)
#
# "("
# bounds: (328,472),(331,472),(331,485),(328,485)
#
# "೧fj"
# bounds: (331,472),(345,472),(345,485),(331,485)
#
# "-"
# bounds: (345,472),(348,472),(348,485),(345,485)
#
# ")"
# bounds: (348,472),(351,472),(351,485),(348,485)
#
# "["
# bounds: (356,472),(359,472),(359,485),(356,485)
#
# "Comp"
# bounds: (360,472),(379,472),(379,485),(360,485)
#
# "-"
# bounds: (380,472),(383,472),(383,485),(380,485)
#
# "1"
# bounds: (384,472),(387,472),(387,485),(384,485)
#
# "other"
# bounds: (393,472),(412,472),(412,485),(393,485)
#
# ","
# bounds: (412,472),(415,472),(415,485),(412,485)
#
# "different"
# bounds: (418,472),(453,472),(453,485),(418,485)
#
# "["
# bounds: (454,472),(457,472),(457,485),(454,485)
#
# "Sk"
# bounds: (459,472),(468,472),(468,485),(459,485)
#
# "."
# bounds: (469,472),(472,472),(472,485),(469,485)
#
# "]"
# bounds: (472,472),(475,472),(475,485),(472,485)
#
# "-"
# bounds: (481,472),(484,472),(484,485),(481,485)
#
# "ness"
# bounds: (42,487),(58,487),(58,499),(42,499)
#
# ","
# bounds: (59,487),(61,487),(61,499),(59,499)
#
# "closeness"
# bounds: (66,487),(100,487),(100,499),(66,499)
#
# ","
# bounds: (103,487),(105,487),(105,499),(103,499)
#
# "straitness"
# bounds: (109,487),(145,487),(145,499),(109,499)
#
# "2"
# bounds: (150,487),(152,487),(152,499),(150,499)
#
# "("
# bounds: (156,487),(158,487),(158,499),(156,499)
#
# "fig"
# bounds: (161,487),(170,487),(170,499),(161,499)
#
# ")"
# bounds: (174,487),(176,487),(176,499),(174,499)
#
# "C©nstriction"
# bounds: (179,487),(227,487),(227,499),(179,499)
#
# ","
# bounds: (228,487),(230,487),(230,499),(228,499)
#
# "tight"
# bounds: (232,487),(252,487),(252,499),(232,499)
#
# "-"
# bounds: (252,487),(254,487),(254,499),(252,499)
#
# "ಬೇರೆಯ"
# bounds: (275,487),(299,487),(299,499),(275,499)
#
# "("
# bounds: (304,487),(306,487),(306,499),(304,499)
#
# "col"
# bounds: (309,487),(319,487),(319,499),(309,499)
#
# "}"
# bounds: (323,487),(325,487),(325,499),(323,499)
#
# "-"
# bounds: (327,487),(329,487),(329,499),(327,499)
#
# "NCSS"
# bounds: (43,503),(59,503),(59,517),(43,517)
#
# "2"
# bounds: (67,503),(70,503),(70,517),(67,517)
#
# "Vi"
# bounds: (78,503),(85,503),(85,517),(78,517)
#
# ","
# bounds: (85,503),(88,503),(88,517),(85,517)
#
# "["
# bounds: (94,503),(97,503),(97,517),(94,517)
#
# "ful"
# bounds: (99,503),(110,503),(110,517),(99,517)
#
# "]"
# bounds: (110,503),(113,503),(113,517),(110,517)
#
# "Iುಡುಕು"
# bounds: (120,503),(161,503),(161,517),(120,517)
#
# "*"
# bounds: (164,503),(167,503),(167,517),(164,517)
#
# "Ich"
# bounds: (172,503),(180,503),(180,517),(172,517)
#
# "be"
# bounds: (184,503),(191,503),(191,517),(184,517)
#
# "full"
# bounds: (196,503),(210,503),(210,517),(196,517)
#
# ","
# bounds: (211,503),(214,503),(214,517),(211,517)
#
# "to"
# bounds: (217,503),(222,503),(222,517),(217,517)
#
# "spread"
# bounds: (229,503),(255,503),(255,517),(229,517)
#
# "qಇತರೇತರ"
# bounds: (263,503),(312,503),(312,517),(263,517)
#
# "itaretara"
# bounds: (321,503),(353,503),(353,517),(321,517)
#
# "["
# bounds: (364,503),(367,503),(367,517),(364,517)
#
# "itaneztam"
# bounds: (368,503),(402,503),(402,517),(368,517)
#
# "]"
# bounds: (404,503),(407,503),(407,517),(404,517)
#
# "adj"
# bounds: (415,503),(427,503),(427,517),(415,517)
#
# "."
# bounds: (427,503),(430,503),(430,517),(427,517)
#
# "["
# bounds: (439,503),(442,503),(442,517),(439,517)
#
# "Soc"
# bounds: (444,503),(453,503),(453,517),(444,517)
#
# "."
# bounds: (454,503),(457,503),(457,517),(454,517)
#
# "]"
# bounds: (458,503),(461,503),(461,517),(458,517)
#
# "IMLI"
# bounds: (469,503),(484,503),(484,517),(469,517)
#
# "everywhere"
# bounds: (44,519),(88,519),(88,532),(44,532)
#
# "("
# bounds: (92,519),(95,519),(95,532),(92,532)
#
# "as"
# bounds: (97,519),(102,519),(102,532),(97,532)
#
# "fragrance"
# bounds: (108,519),(145,519),(145,532),(108,532)
#
# ","
# bounds: (147,519),(150,519),(150,532),(147,532)
#
# "SIncl"
# bounds: (153,519),(175,519),(175,532),(153,532)
#
# ","
# bounds: (175,519),(178,519),(178,532),(175,532)
#
# "SIMwake"
# bounds: (182,519),(208,519),(208,532),(182,532)
#
# ","
# bounds: (207,519),(210,519),(210,532),(207,532)
#
# "fame"
# bounds: (214,519),(235,519),(235,532),(214,532)
#
# ","
# bounds: (235,519),(238,519),(238,532),(235,532)
#
# "etc"
# bounds: (242,519),(252,519),(252,532),(242,532)
#
# "."
# bounds: (252,519),(255,519),(255,532),(252,532)
#
# "tual"
# bounds: (271,519),(286,519),(286,532),(271,532)
#
# ","
# bounds: (287,519),(290,519),(290,532),(287,532)
#
# "TecipICKLal"
# bounds: (296,519),(333,519),(333,532),(296,532)
#
# "–"
# bounds: (340,519),(343,519),(343,532),(340,532)
#
# "ಮಿತ್ರರು"
# bounds: (350,519),(373,519),(373,532),(350,532)
#
# "ಇತರೇತರ"
# bounds: (380,519),(407,519),(407,532),(380,532)
#
# "ಆ"
# bounds: (414,519),(417,519),(417,532),(414,532)
#
# "ವಾರ"
# bounds: (424,519),(443,519),(443,532),(424,532)
#
# "ಮಾಡಿದರು"
# bounds: (449,519),(481,519),(481,532),(449,532)
#
# "."
# bounds: (483,519),(486,519),(486,532),(483,532)
#
# "in"
# bounds: (42,534),(49,534),(49,545),(42,545)
#
# "a"
# bounds: (54,534),(56,534),(56,545),(54,545)
#
# "space"
# bounds: (59,534),(81,534),(81,545),(59,545)
#
# ")"
# bounds: (83,534),(85,534),(85,545),(83,545)
#
# "["
# bounds: (89,534),(91,534),(91,545),(89,545)
#
# "Ka"
# bounds: (91,534),(104,534),(104,545),(91,545)
#
# "."
# bounds: (103,534),(105,534),(105,545),(103,545)
#
# "D445"
# bounds: (112,534),(129,534),(129,545),(112,545)
#
# "]"
# bounds: (132,534),(134,534),(134,545),(132,545)
#
# "."
# bounds: (135,534),(137,534),(137,545),(135,545)
#
# "The"
# bounds: (275,535),(284,535),(284,545),(275,545)
#
# "friends"
# bounds: (289,535),(313,535),(313,545),(289,545)
#
# "extended"
# bounds: (317,535),(348,535),(348,545),(317,545)
#
# "Imutual"
# bounds: (351,535),(376,535),(376,545),(351,545)
#
# "help"
# bounds: (380,535),(391,535),(391,545),(380,545)
#
# "."
# bounds: (395,535),(397,535),(397,545),(395,545)
#
# "["
# bounds: (403,535),(405,535),(405,545),(403,545)
#
# "Sk"
# bounds: (408,535),(415,535),(415,545),(408,545)
#
# "]"
# bounds: (420,535),(422,535),(422,545),(420,545)
#
# "."
# bounds: (422,535),(424,535),(424,545),(422,545)
#
# "ಇಡುಗೆ"
# bounds: (41,553),(70,553),(70,564),(41,564)
#
# "iduge"
# bounds: (76,553),(98,553),(98,564),(76,564)
#
# "("
# bounds: (103,553),(105,553),(105,564),(103,564)
#
# "kly"
# bounds: (106,552),(128,552),(128,564),(106,564)
#
# "]"
# bounds: (130,552),(132,552),(132,563),(130,563)
#
# "."
# bounds: (141,552),(143,552),(143,563),(141,563)
#
# "["
# bounds: (149,552),(151,552),(151,563),(149,563)
#
# "move"
# bounds: (154,552),(171,552),(171,563),(154,563)
#
# "]"
# bounds: (173,552),(175,552),(175,563),(173,563)
#
# "1"
# bounds: (181,552),(183,552),(183,563),(181,563)
#
# "["
# bounds: (189,552),(191,552),(191,563),(189,563)
#
# "om"
# bounds: (195,552),(205,552),(205,563),(195,563)
#
# "."
# bounds: (206,552),(209,552),(209,563),(206,563)
#
# "]"
# bounds: (209,552),(211,552),(211,563),(209,563)
#
# "ornament"
# bounds: (218,552),(254,552),(254,563),(218,563)
#
# "ಇತಿ"
# bounds: (270,551),(285,551),(285,562),(270,562)
#
# "iti"
# bounds: (290,551),(298,551),(298,562),(290,562)
#
# "["
# bounds: (306,551),(308,551),(308,562),(306,562)
#
# "it"
# bounds: (310,551),(315,551),(315,562),(310,562)
#
# "]"
# bounds: (318,551),(320,551),(320,562),(318,562)
#
# "Latv"
# bounds: (339,551),(351,551),(351,562),(339,562)
#
# ":"
# bounds: (353,551),(355,551),(355,562),(353,562)
#
# "["
# bounds: (361,551),(364,551),(364,562),(361,562)
#
# "manner"
# bounds: (366,551),(392,551),(392,562),(366,562)
#
# ")"
# bounds: (395,551),(397,551),(397,562),(395,562)
#
# "adv"
# bounds: (403,550),(416,550),(416,562),(403,562)
#
# ","
# bounds: (417,550),(419,550),(419,561),(417,561)
#
# "80"
# bounds: (425,550),(431,550),(431,561),(425,561)
#
# ","
# bounds: (433,550),(435,550),(435,561),(433,561)
#
# "thus"
# bounds: (438,550),(455,550),(455,561),(438,561)
#
# ","
# bounds: (456,550),(458,550),(458,561),(456,561)
#
# "there"
# bounds: (462,550),(484,550),(484,561),(462,561)
#
# "("
# bounds: (42,569),(44,569),(44,580),(42,580)
#
# "that"
# bounds: (45,569),(61,569),(61,580),(45,580)
#
# "has"
# bounds: (65,569),(75,569),(75,580),(65,580)
#
# "been"
# bounds: (80,569),(97,569),(97,580),(80,580)
#
# "WDrm"
# bounds: (102,568),(121,568),(121,580),(102,580)
#
# ")"
# bounds: (122,568),(124,568),(124,579),(122,579)
#
# "2"
# bounds: (130,568),(132,568),(132,579),(130,579)
#
# "["
# bounds: (136,568),(139,568),(139,579),(136,579)
#
# "com"
# bounds: (143,568),(155,568),(155,579),(143,579)
#
# "]"
# bounds: (161,568),(163,568),(163,579),(161,579)
#
# "deposit"
# bounds: (169,568),(196,568),(196,579),(169,579)
#
# "["
# bounds: (199,568),(201,568),(201,579),(199,579)
#
# "Ka"
# bounds: (204,568),(214,568),(214,579),(204,579)
#
# "."
# bounds: (215,568),(217,568),(217,579),(215,579)
#
# "D442"
# bounds: (222,568),(243,568),(243,579),(222,579)
#
# "]"
# bounds: (244,568),(246,568),(246,579),(244,579)
#
# ","
# bounds: (247,568),(249,568),(249,579),(247,579)
#
# "fore"
# bounds: (272,567),(288,567),(288,578),(272,578)
#
# "1"
# bounds: (293,567),(295,567),(295,578),(293,578)
#
# "."
# bounds: (300,567),(302,567),(302,578),(300,578)
#
# "."
# bounds: (304,567),(306,567),(306,578),(304,578)
#
# "."
# bounds: (307,567),(309,567),(309,578),(307,578)
#
# "."
# bounds: (314,567),(316,567),(316,578),(314,578)
#
# "ಇತಿ"
# bounds: (321,567),(331,567),(331,578),(321,578)
#
# "ನಿಮ್ಮ"
# bounds: (338,567),(346,567),(346,578),(338,578)
#
# "ವಿಶ್ವಾಸಿ"
# bounds: (360,567),(380,567),(380,578),(360,578)
#
# "-"
# bounds: (382,567),(384,567),(384,578),(382,578)
#
# "nr"
# bounds: (385,567),(391,567),(391,578),(385,578)
#
# ","
# bounds: (396,567),(398,567),(398,578),(396,578)
#
# "slockerely"
# bounds: (404,566),(434,566),(434,578),(404,578)
#
# "WCurs"
# bounds: (439,566),(458,566),(458,577),(439,577)
#
# "2"
# bounds: (468,566),(470,566),(470,577),(468,577)
#
# "."
# bounds: (480,566),(482,566),(482,577),(480,577)
#
# "."
# bounds: (482,566),(484,566),(484,577),(482,577)
#
# "["
# bounds: (273,582),(276,582),(276,592),(273,592)
#
# "end"
# bounds: (278,582),(290,582),(290,592),(278,592)
#
# "]"
# bounds: (291,582),(293,582),(293,592),(291,592)
#
# "end"
# bounds: (301,582),(312,582),(312,592),(301,592)
#
# ","
# bounds: (314,582),(316,582),(316,592),(314,592)
#
# "COInclusion"
# bounds: (321,582),(362,582),(362,592),(321,592)
#
# "1"
# bounds: (367,582),(369,582),(369,592),(367,592)
#
# "ಈ"
# bounds: (377,582),(379,582),(379,592),(377,592)
#
# "ಪ್ರಸ್ತಾವಕ್ಕೆ"
# bounds: (387,582),(415,582),(415,592),(387,592)
#
# "ಪ್ರತಿ"
# bounds: (423,582),(433,582),(433,592),(423,592)
#
# "ಆಗಿದೆ"
# bounds: (438,582),(455,582),(455,592),(438,592)
#
# "."
# bounds: (455,582),(457,582),(457,592),(455,592)
#
# "This"
# bounds: (462,582),(476,582),(476,592),(462,592)
#
# "is"
# bounds: (479,582),(485,582),(485,592),(479,592)
#
# "*"
# bounds: (35,587),(37,587),(37,598),(35,598)
#
# "ಇಡುಪು"
# bounds: (40,587),(76,587),(76,598),(40,598)
#
# "iduNu"
# bounds: (77,587),(97,587),(97,598),(77,598)
#
# "["
# bounds: (103,587),(105,587),(105,598),(103,598)
#
# "iqu"
# bounds: (107,587),(133,587),(133,598),(107,598)
#
# "]"
# bounds: (131,587),(133,587),(133,598),(131,598)
#
# "."
# bounds: (140,587),(142,587),(142,598),(140,598)
#
# "["
# bounds: (146,587),(149,587),(149,598),(146,598)
#
# "break"
# bounds: (152,587),(170,587),(170,598),(152,598)
#
# "]"
# bounds: (173,587),(175,587),(175,598),(173,598)
#
# "beach"
# bounds: (177,587),(204,587),(204,598),(177,598)
#
# ","
# bounds: (205,587),(207,587),(207,598),(205,598)
#
# "break"
# bounds: (210,587),(231,587),(231,598),(210,598)
#
# ","
# bounds: (233,587),(235,587),(235,598),(233,598)
#
# "hole"
# bounds: (239,587),(254,587),(254,598),(239,598)
#
# "3finished"
# bounds: (273,597),(307,597),(307,608),(273,608)
#
# "matter"
# bounds: (311,597),(332,597),(332,608),(311,608)
#
# "."
# bounds: (333,597),(335,597),(335,608),(333,608)
#
# "["
# bounds: (341,597),(343,597),(343,608),(341,608)
#
# "Sk"
# bounds: (347,597),(354,597),(354,608),(347,608)
#
# "]"
# bounds: (357,597),(362,597),(362,608),(357,608)
#
# "("
# bounds: (42,602),(44,602),(44,613),(42,613)
#
# "Kit"
# bounds: (45,602),(55,602),(55,613),(45,613)
#
# "."
# bounds: (55,602),(57,602),(57,613),(55,613)
#
# ")"
# bounds: (59,602),(61,602),(61,613),(59,613)
#
# "["
# bounds: (67,602),(69,602),(69,613),(67,613)
#
# "Ka"
# bounds: (70,602),(82,602),(82,613),(70,613)
#
# "."
# bounds: (83,602),(85,602),(85,613),(83,613)
#
# "1432"
# bounds: (90,602),(109,602),(109,613),(90,613)
#
# "]"
# bounds: (111,602),(113,602),(113,613),(111,613)
#
# "."
# bounds: (114,602),(116,602),(116,613),(114,613)
#
# "="
# bounds: (270,614),(272,614),(272,624),(270,624)
#
# "ಇತಿ"
# bounds: (278,614),(292,614),(292,624),(278,624)
#
# "-"
# bounds: (298,614),(300,614),(300,624),(298,624)
#
# "iti"
# bounds: (300,614),(308,614),(308,624),(300,624)
#
# "["
# bounds: (317,614),(319,614),(319,624),(317,624)
#
# "iti"
# bounds: (319,614),(327,614),(327,624),(319,624)
#
# "]"
# bounds: (329,614),(331,614),(331,624),(329,624)
#
# "Sugf"
# bounds: (336,614),(345,614),(345,624),(336,624)
#
# "."
# bounds: (347,614),(349,614),(349,624),(347,624)
#
# "["
# bounds: (356,614),(358,614),(358,624),(356,624)
#
# "gramLY"
# bounds: (362,614),(385,614),(385,624),(362,624)
#
# "a"
# bounds: (391,614),(393,614),(393,624),(391,624)
#
# "suffix"
# bounds: (397,614),(419,614),(419,624),(397,624)
#
# "to"
# bounds: (424,614),(430,614),(430,624),(424,624)
#
# "forIn"
# bounds: (435,614),(453,614),(453,624),(435,624)
#
# "fermin"
# bounds: (459,614),(484,614),(484,624),(459,624)
#
# "•ಇಡುರು"
# bounds: (32,620),(73,620),(73,632),(32,632)
#
# "iduu"
# bounds: (80,620),(102,620),(102,632),(80,632)
#
# "["
# bounds: (109,620),(111,620),(111,632),(109,632)
#
# "idini"
# bounds: (112,620),(133,620),(133,632),(112,632)
#
# "]"
# bounds: (134,620),(136,620),(136,632),(134,632)
#
# "K"
# bounds: (143,620),(145,620),(145,632),(143,632)
#
# "."
# bounds: (147,620),(149,620),(149,632),(147,632)
#
# "["
# bounds: (156,620),(159,620),(159,632),(156,632)
#
# "trouble"
# bounds: (162,620),(184,620),(184,632),(162,632)
#
# "]"
# bounds: (187,620),(189,620),(189,632),(187,632)
#
# "1"
# bounds: (195,620),(197,620),(197,632),(195,632)
#
# "imprediment"
# bounds: (202,620),(252,620),(252,632),(202,632)
#
# ","
# bounds: (252,620),(254,620),(254,632),(252,632)
#
# "ine"
# bounds: (273,629),(283,629),(283,639),(273,639)
#
# "nuns"
# bounds: (285,629),(310,629),(310,639),(285,639)
#
# "from"
# bounds: (314,629),(332,629),(332,639),(314,639)
#
# "ITICuline"
# bounds: (336,629),(377,629),(377,639),(336,639)
#
# "nouns"
# bounds: (379,629),(402,629),(402,639),(379,639)
#
# "1"
# bounds: (407,629),(409,629),(409,639),(407,639)
#
# "ಮಡಿವಳ"
# bounds: (414,629),(442,629),(442,639),(414,639)
#
# "Washerman"
# bounds: (445,629),(485,629),(485,639),(445,639)
#
# "hindranCe"
# bounds: (43,636),(82,636),(82,648),(43,648)
#
# "2"
# bounds: (86,636),(88,636),(88,648),(86,648)
#
# "trouble"
# bounds: (93,636),(121,636),(121,648),(93,648)
#
# "3"
# bounds: (125,636),(127,636),(127,648),(125,648)
#
# "["
# bounds: (133,636),(135,636),(135,648),(133,648)
#
# "mind"
# bounds: (139,636),(155,636),(155,648),(139,648)
#
# ")"
# bounds: (156,636),(158,636),(158,648),(156,648)
#
# "enmity"
# bounds: (165,636),(189,636),(189,648),(165,648)
#
# "["
# bounds: (195,636),(197,636),(197,648),(195,648)
#
# "Ka"
# bounds: (199,636),(209,636),(209,648),(199,648)
#
# "."
# bounds: (210,636),(212,636),(212,648),(210,648)
#
# "1435"
# bounds: (218,636),(237,636),(237,648),(218,648)
#
# "]"
# bounds: (238,636),(240,636),(240,648),(238,648)
#
# "."
# bounds: (242,636),(244,636),(244,648),(242,648)
#
# "frವ"
# bounds: (279,643),(291,643),(291,655),(279,655)
#
# "ದಿವತಿ"
# bounds: (296,643),(319,643),(319,655),(296,655)
#
# "WasheraNiMa"
# bounds: (322,643),(368,643),(368,655),(322,655)
#
# "."
# bounds: (376,643),(378,643),(378,655),(376,655)
#
# "ಇಡುಎಕೆ"
# bounds: (41,654),(76,655),(76,667),(41,666)
#
# "iduvike"
# bounds: (84,655),(115,655),(115,666),(84,666)
#
# "["
# bounds: (120,655),(122,655),(122,666),(120,666)
#
# "i"
# bounds: (124,655),(126,655),(126,666),(124,666)
#
# "«"
# bounds: (126,655),(128,655),(128,666),(126,666)
#
# "ddy"
# bounds: (128,655),(141,655),(141,667),(128,667)
#
# "'"
# bounds: (141,656),(143,656),(143,667),(141,667)
#
# "ke"
# bounds: (143,656),(153,656),(153,667),(143,667)
#
# "]"
# bounds: (155,656),(157,656),(157,667),(155,667)
#
# "M"
# bounds: (162,656),(164,656),(164,667),(162,667)
#
# "."
# bounds: (167,656),(169,656),(169,667),(167,667)
#
# "["
# bounds: (175,656),(177,656),(177,667),(175,667)
#
# "mದVE"
# bounds: (182,656),(198,656),(198,667),(182,667)
#
# "]"
# bounds: (199,657),(201,657),(201,668),(199,668)
#
# "putting"
# bounds: (208,657),(234,657),(234,668),(208,668)
#
# ","
# bounds: (238,657),(240,657),(240,668),(238,668)
#
# "Mp"
# bounds: (244,657),(251,657),(251,668),(244,668)
#
# "-"
# bounds: (252,657),(254,657),(254,668),(252,668)
#
# "ಇತಿಮಿತಿ"
# bounds: (272,658),(308,659),(308,670),(272,669)
#
# "itirmiti"
# bounds: (313,658),(337,658),(337,670),(313,670)
#
# "["
# bounds: (345,659),(347,659),(347,670),(345,670)
#
# "itimiti"
# bounds: (348,659),(373,659),(373,670),(348,670)
#
# "]"
# bounds: (373,659),(375,659),(375,670),(373,670)
#
# ","
# bounds: (385,659),(387,659),(387,670),(385,670)
#
# "["
# bounds: (394,660),(396,660),(396,671),(394,671)
#
# "["
# bounds: (396,660),(398,660),(398,671),(396,671)
#
# "end"
# bounds: (400,660),(411,660),(411,671),(400,671)
#
# "|"
# bounds: (414,660),(416,660),(416,671),(414,671)
#
# "limit"
# bounds: (422,660),(440,660),(440,671),(422,671)
#
# ","
# bounds: (441,660),(444,660),(444,671),(441,671)
#
# "b•Sunds"
# bounds: (450,660),(475,660),(475,672),(450,672)
#
# "!"
# bounds: (481,661),(483,661),(483,672),(481,672)
#
# "plying"
# bounds: (43,671),(66,671),(66,684),(43,684)
#
# ","
# bounds: (68,671),(71,671),(71,684),(68,684)
#
# "planting"
# bounds: (74,671),(104,671),(104,684),(74,684)
#
# ","
# bounds: (107,671),(110,671),(110,684),(107,684)
#
# "producing"
# bounds: (113,671),(152,671),(152,684),(113,684)
#
# ","
# bounds: (153,671),(156,671),(156,684),(153,684)
#
# "etc"
# bounds: (159,671),(168,671),(168,684),(159,684)
#
# "."
# bounds: (170,671),(173,671),(173,684),(170,684)
#
# "["
# bounds: (175,671),(178,671),(178,684),(175,684)
#
# "Ka"
# bounds: (180,671),(192,671),(192,684),(180,684)
#
# "D442"
# bounds: (198,671),(220,671),(220,684),(198,684)
#
# "]"
# bounds: (219,671),(222,671),(222,684),(219,684)
#
# "."
# bounds: (223,671),(226,671),(226,684),(223,684)
#
# "ಅವನ"
# bounds: (275,674),(291,674),(291,686),(275,686)
#
# "ಆಸೆಗೆ"
# bounds: (296,674),(312,674),(312,686),(296,686)
#
# "ಇತಿಮಿತಿಯೇ"
# bounds: (314,674),(350,674),(350,686),(314,686)
#
# "ಇಲ್ಲ"
# bounds: (356,674),(370,674),(370,686),(356,686)
#
# "."
# bounds: (372,674),(374,674),(374,686),(372,686)
#
# "There"
# bounds: (379,674),(396,674),(396,686),(379,686)
#
# "is"
# bounds: (401,674),(405,674),(405,686),(401,686)
#
# "no"
# bounds: (409,674),(417,674),(417,686),(409,686)
#
# "limit"
# bounds: (420,674),(438,674),(438,686),(420,686)
#
# "at"
# bounds: (441,674),(447,674),(447,686),(441,686)
#
# "all"
# bounds: (450,674),(459,674),(459,686),(450,686)
#
# "for"
# bounds: (462,674),(470,674),(470,686),(462,686)
#
# "his"
# bounds: (476,674),(485,674),(485,686),(476,686)
#
# "•ಇಡುವು"
# bounds: (32,688),(76,688),(76,701),(32,701)
#
# "iduvu"
# bounds: (79,688),(102,688),(102,701),(79,701)
#
# "["
# bounds: (109,689),(112,689),(112,702),(109,702)
#
# "idduviu"
# bounds: (114,689),(135,689),(135,702),(114,702)
#
# "]"
# bounds: (135,689),(138,689),(138,702),(135,702)
#
# "H"
# bounds: (143,689),(146,689),(146,702),(143,702)
#
# "."
# bounds: (149,689),(152,689),(152,702),(149,702)
#
# "["
# bounds: (157,689),(160,689),(160,702),(157,702)
#
# "೧nass"
# bounds: (162,689),(178,689),(178,702),(162,702)
#
# "]"
# bounds: (180,689),(183,689),(183,702),(180,702)
#
# "]"
# bounds: (183,689),(186,689),(186,702),(183,702)
#
# "heap"
# bounds: (190,689),(206,689),(206,702),(190,702)
#
# ","
# bounds: (208,689),(211,689),(211,702),(208,702)
#
# "IMALSS"
# bounds: (214,689),(233,689),(233,702),(214,702)
#
# "("
# bounds: (237,689),(240,689),(240,702),(237,702)
#
# "KA"
# bounds: (243,689),(252,689),(252,702),(243,702)
#
# ","
# bounds: (253,690),(256,690),(256,703),(253,703)
#
# "greed"
# bounds: (274,690),(291,690),(291,703),(274,703)
#
# "."
# bounds: (293,690),(296,690),(296,703),(293,703)
#
# "["
# bounds: (302,690),(305,690),(305,703),(302,703)
#
# "Sk"
# bounds: (306,690),(312,690),(312,703),(306,703)
#
# "."
# bounds: (314,690),(317,690),(317,703),(314,703)
#
# "]"
# bounds: (318,690),(323,690),(323,703),(318,703)
#
# "1440"
# bounds: (44,705),(63,705),(63,716),(44,716)
#
# "]"
# bounds: (64,705),(66,705),(66,716),(64,716)
#
# "."
# bounds: (68,705),(70,705),(70,716),(68,716)
#
# "ಇತಿಶ್ರೀ"
# bounds: (270,707),(291,707),(291,720),(270,720)
#
# "itisrI"
# bounds: (305,707),(324,707),(324,720),(305,720)
#
# "["
# bounds: (329,707),(332,707),(332,720),(329,720)
#
# "it"
# bounds: (333,707),(339,707),(339,720),(333,720)
#
# "/"
# bounds: (340,707),(343,707),(343,720),(340,720)
#
# "n"
# bounds: (346,707),(349,707),(349,720),(346,720)
#
# "]"
# bounds: (353,707),(356,707),(356,720),(353,720)
#
# "."
# bounds: (366,707),(369,707),(369,720),(366,720)
#
# "["
# bounds: (374,707),(377,707),(377,720),(374,720)
#
# "end"
# bounds: (379,707),(392,707),(392,720),(379,720)
#
# "]"
# bounds: (392,707),(395,707),(395,720),(392,720)
#
# "COnclusion"
# bounds: (400,707),(443,707),(443,720),(400,720)
#
# ","
# bounds: (445,707),(448,707),(448,720),(445,720)
#
# "end"
# bounds: (452,707),(464,707),(464,720),(452,720)
#
# ","
# bounds: (465,707),(468,707),(468,720),(465,720)
#
# "fin"
# bounds: (472,707),(484,707),(484,720),(472,720)
#
# "•ಇಡ"
# bounds: (32,722),(56,722),(56,734),(32,734)
#
# "ide"
# bounds: (61,722),(73,722),(73,734),(61,734)
#
# "["
# bounds: (77,722),(79,722),(79,734),(77,734)
#
# "id"
# bounds: (81,722),(87,722),(87,734),(81,734)
#
# "]"
# bounds: (94,722),(96,722),(96,734),(94,734)
#
# "n"
# bounds: (99,722),(101,722),(101,734),(99,734)
#
# "."
# bounds: (104,722),(106,722),(106,734),(104,734)
#
# "["
# bounds: (111,722),(113,722),(113,734),(111,734)
#
# "lowc"
# bounds: (115,722),(124,722),(124,734),(115,734)
#
# "]"
# bounds: (130,722),(133,722),(133,734),(130,734)
#
# "1"
# bounds: (137,722),(139,722),(139,734),(137,734)
#
# "place"
# bounds: (143,722),(164,722),(164,734),(143,734)
#
# ","
# bounds: (164,722),(166,722),(166,734),(164,734)
#
# "sprot"
# bounds: (170,722),(186,722),(186,734),(170,734)
#
# ","
# bounds: (187,722),(189,722),(189,734),(187,734)
#
# "ground"
# bounds: (192,722),(218,722),(218,734),(192,734)
#
# "2"
# bounds: (224,722),(226,722),(226,734),(224,734)
#
# "space"
# bounds: (229,722),(252,722),(252,734),(229,734)
#
# ","
# bounds: (252,722),(254,722),(254,734),(252,734)
#
# "ish"
# bounds: (272,722),(282,722),(282,734),(272,734)
#
# "ಅವನ"
# bounds: (297,722),(312,722),(312,734),(297,734)
#
# "ಕಷ್ಟದ"
# bounds: (316,722),(336,722),(336,734),(316,734)
#
# "ದಾಳಿಗೆ"
# bounds: (342,722),(359,722),(359,734),(342,734)
#
# "ಇತಿಶ್ರೀ"
# bounds: (367,722),(378,722),(378,734),(367,734)
#
# "ಆಯಿತು"
# bounds: (388,722),(414,722),(414,734),(388,734)
#
# "."
# bounds: (413,722),(415,722),(415,734),(413,734)
#
# "His"
# bounds: (421,722),(430,722),(430,734),(421,734)
#
# "struggling"
# bounds: (434,722),(469,722),(469,734),(434,734)
#
# "life"
# bounds: (472,722),(482,722),(482,734),(472,734)
#
# "TOOM"
# bounds: (43,739),(61,739),(61,750),(43,750)
#
# ","
# bounds: (64,739),(66,739),(66,750),(64,750)
#
# "Capaciousness"
# bounds: (70,739),(125,739),(125,750),(70,750)
#
# "or"
# bounds: (129,739),(137,739),(137,750),(129,750)
#
# "ability"
# bounds: (139,739),(164,739),(164,750),(139,750)
#
# "tD"
# bounds: (167,739),(174,739),(174,750),(167,750)
#
# "ACCOImmodate"
# bounds: (179,739),(232,739),(232,750),(179,750)
#
# "CID"
# bounds: (238,739),(244,739),(244,750),(238,750)
#
# "-"
# bounds: (253,739),(255,739),(255,750),(253,750)
#
# "CarThe"
# bounds: (273,739),(291,739),(291,750),(273,750)
#
# "an"
# bounds: (304,739),(310,739),(310,750),(304,750)
#
# "end"
# bounds: (315,739),(326,739),(326,750),(315,750)
#
# "."
# bounds: (327,739),(329,739),(329,750),(327,750)
#
# "["
# bounds: (335,739),(337,739),(337,750),(335,750)
#
# "Sk"
# bounds: (341,739),(347,739),(347,750),(341,750)
#
# "]"
# bounds: (352,739),(354,739),(354,750),(352,750)
#
# "."
# bounds: (356,739),(358,739),(358,750),(356,750)
#
# "tents"
# bounds: (41,753),(60,753),(60,765),(41,765)
#
# "["
# bounds: (64,753),(66,753),(66,765),(64,765)
#
# "Ka"
# bounds: (69,753),(77,753),(77,765),(69,765)
#
# "."
# bounds: (80,753),(82,753),(82,765),(80,765)
#
# "ID434"
# bounds: (85,753),(106,753),(106,765),(85,765)
#
# "]"
# bounds: (107,753),(109,753),(109,765),(107,765)
#
# "."
# bounds: (111,753),(113,753),(113,765),(111,765)
#
# "ಇತಿಹಾಸ"
# bounds: (271,754),(309,754),(309,767),(271,767)
#
# "itihasa"
# bounds: (311,754),(337,754),(337,767),(311,767)
#
# "["
# bounds: (343,754),(346,754),(346,767),(343,767)
#
# "ithy"
# bounds: (348,754),(363,754),(363,767),(348,767)
#
# ":"
# bounds: (364,754),(367,754),(367,767),(364,767)
#
# "Sa"
# bounds: (369,754),(375,754),(375,767),(369,767)
#
# "]"
# bounds: (376,754),(379,754),(379,767),(376,767)
#
# "."
# bounds: (388,754),(391,754),(391,767),(388,767)
#
# "["
# bounds: (395,754),(398,754),(398,767),(395,767)
#
# "his"
# bounds: (400,754),(409,754),(409,767),(400,767)
#
# "."
# bounds: (409,754),(412,754),(412,767),(409,767)
#
# "["
# bounds: (411,754),(414,754),(414,767),(411,767)
#
# "history"
# bounds: (420,754),(447,754),(447,767),(420,767)
#
# "["
# bounds: (449,754),(452,754),(452,767),(449,767)
#
# "Sk"
# bounds: (454,754),(463,754),(463,767),(454,767)
#
# "."
# bounds: (464,754),(467,754),(467,767),(464,767)
#
# "]"
# bounds: (466,754),(469,754),(469,767),(466,767)
#
# "."
# bounds: (470,754),(473,754),(473,767),(470,767)

# %%
def dt(path):
    """Detects text in the file."""
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    print('Texts:')

    for text in texts:
        print('\n"{}"'.format(text.description))

#         vertices = (['({},{})'.format(vertex.x, vertex.y)
#                     for vertex in text.bounding_poly.vertices])

#         print('bounds: {}'.format(','.join(vertices)))

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(
                response.error.message))

# %%
for img in glob.glob('10.4img/*'):
# for i in range(1,4):
#     img = str(i) + ".jpg"
    dt(img)
# Out:
# Texts:
#
# "॥व्याकरपभहाभाष्यम् ॥
# [म० १.१.९.
# भवत्यागमकालेन स्वाध्यायकालेन प्रवचनकालेन व्यवहारकालेनेति । तत्र चागमका-
# लेनैवायुः पर्युपयुक्तं स्यात् । तस्मादनभ्युपायः शब्हानां प्रतिपत्तौ प्रतिपदपाठ: ॥
# कथं तरहीमे शब्दा: प्रतिपत्तव्याः | किंचित्सामान्यविशेषव्लक्षण प्रवर्त्ये येनाल्पेन
# यत्नेन महतो महतः शब्दौघान्प्रतिपद्येरन् । किं पुनर्तत् । उत्सर्गापवादौ । कश्चि-
# 5 दुत्सर्गः कर्तव्यः कश्चिदपवादः | कथंजातीयकः पुनरुत्सर्गः कर्तव्यः कर्यंजातीयको
# ऽपवादः । सामान्येनोत्सर्गः कर्तव्यः । सद्यथा | कर्मण्यण [३ .२.१]। तस्य विशे-
# बेणापवादः । तव्यथा | आतो ऽ्नुपसरगै कः [३.२.३] ।।
# किं पुनराकृति: पदार्थ आहोस्विर्रव्यम् । उभयमित्याह | कथं ज्ञायते । उभ-
# यथा दाचार्येण सूत्राणि पठितानि | आकृ्ति पदार्थ मत्वा जात्याख्यायामेक-
# 10 स्मिन्बहवचनमन्यतरस्याम् [१. २. ९८] इस्युच्यते | द्रव्यं पदार्थ मत्या सरू-
# पाणाम् [१. २. ६४ ] इत्येकशेष आरम्यते ॥
# किं पुनर्नित्यः शुब्द आहोस्वित्कार्यः | संग्रह एतत्पाधान्येन परीक्षितं नित्यो
# वा स्यात्कार्यों बेति | तत्रोक्ता दोषाः प्रयोजनान्यप्युक्तानि । तत्र त्वेष निर्णयो
# येव नित्यो s्यापि कार्य उभयथापि लक्षणं प्रवर्त्येमिति | | कथं पुनरिदं भगवतः
# 15 पाणिनेराचार्यस्य लक्षणं प्रवृत्तम् ।
# सिद्धे शब्दार्थसंबन्धे
# सिद्धे शब्दे ऽर्थे संबन्धे चेति | अथ सिद्धशष्दस्य कः पदार्थ: | नित्यपर्यायवाची
# सिद्शब्दः | करथं ज्ञायते । यत्कूटस्थेष्वाविचालिषु भावेषु वतैते | त्था | सिद्धा
# यौः सिद्धा पृथिवी सिद्धमाकाशमिति | ननु च भौः कार्येष्वपि वर्तते | तद्यथा ।
# 20 सिद्ध भदन: सिद्धः सूपः सिद्धा यवागूरिति । यावता कार्येष्वपि वर्तते तत्र कुत
# एतभित्यपर्यायवाचिनो ग्रहणं न पुनः कार्ये यः सिद्धशब्द हति | संग्रहे तावल्कार्य-
# प्रतिहन्दिभावान्मन्यामहे नित्यपर्यायवाचिनो ग्रहणमिति | इहापि तदैव || अथवा
# सन्त्येकपदान्यप्यवधारणानि | तद्यथाब्भक्षो वायुभक्ष इत्यप एव भक्षयति वायुमेव
# 25 भक्षयतीति गम्यत एवमिहापि सिद्ध एव न साध्य इति ॥ अथवा पूर्वपदलोपो sत्र
# दष्टव्यः । अल्यन्तसिद्धः सिद्ध इति | तथ्यथा । देवदत्तो दत्तः सत्यभामा भामेति ॥
# अथवा व्याख्यानतो विशेषमतिपत्तिर्न हि संदेहादलक्षणमिति नित्यपर्यायवाचिनो
# अ्रहणमिति व्याख्यास्यामः ॥ किं पुनरनेन वर्ण्येन किं न महता कण्डेन नित्यशभ्द
# यस्मिच्ुपादीयमाने ऽसंदेहः स्यात् । मङ्गलार्यम् । माङ्गलिक आचार्यों
# एवोपात्तो
# in
# "
#
# "॥व्याकरपभहाभाष्यम्"
#
# "॥"
#
# "[म०"
#
# "१.१.९."
#
# "भवत्यागमकालेन"
#
# "स्वाध्यायकालेन"
#
# "प्रवचनकालेन"
#
# "व्यवहारकालेनेति"
#
# "।"
#
# "तत्र"
#
# "चागमका-"
#
# "लेनैवायुः"
#
# "पर्युपयुक्तं"
#
# "स्यात्"
#
# "।"
#
# "तस्मादनभ्युपायः"
#
# "शब्हानां"
#
# "प्रतिपत्तौ"
#
# "प्रतिपदपाठ:"
#
# "॥"
#
# "कथं"
#
# "तरहीमे"
#
# "शब्दा:"
#
# "प्रतिपत्तव्याः"
#
# "|"
#
# "किंचित्सामान्यविशेषव्लक्षण"
#
# "प्रवर्त्ये"
#
# "येनाल्पेन"
#
# "यत्नेन"
#
# "महतो"
#
# "महतः"
#
# "शब्दौघान्प्रतिपद्येरन्"
#
# "।"
#
# "किं"
#
# "पुनर्तत्"
#
# "।"
#
# "उत्सर्गापवादौ"
#
# "।"
#
# "कश्चि-"
#
# "5"
#
# "दुत्सर्गः"
#
# "कर्तव्यः"
#
# "कश्चिदपवादः"
#
# "|"
#
# "कथंजातीयकः"
#
# "पुनरुत्सर्गः"
#
# "कर्तव्यः"
#
# "कर्यंजातीयको"
#
# "ऽपवादः"
#
# "।"
#
# "सामान्येनोत्सर्गः"
#
# "कर्तव्यः"
#
# "।"
#
# "सद्यथा"
#
# "|"
#
# "कर्मण्यण"
#
# "[३"
#
# ".२.१]।"
#
# "तस्य"
#
# "विशे-"
#
# "बेणापवादः"
#
# "।"
#
# "तव्यथा"
#
# "|"
#
# "आतो"
#
# "ऽ्नुपसरगै"
#
# "कः"
#
# "[३.२.३]"
#
# "।।"
#
# "किं"
#
# "पुनराकृति:"
#
# "पदार्थ"
#
# "आहोस्विर्रव्यम्"
#
# "।"
#
# "उभयमित्याह"
#
# "|"
#
# "कथं"
#
# "ज्ञायते"
#
# "।"
#
# "उभ-"
#
# "यथा"
#
# "दाचार्येण"
#
# "सूत्राणि"
#
# "पठितानि"
#
# "|"
#
# "आकृ्ति"
#
# "पदार्थ"
#
# "मत्वा"
#
# "जात्याख्यायामेक-"
#
# "10"
#
# "स्मिन्बहवचनमन्यतरस्याम्"
#
# "[१."
#
# "२."
#
# "९८]"
#
# "इस्युच्यते"
#
# "|"
#
# "द्रव्यं"
#
# "पदार्थ"
#
# "मत्या"
#
# "सरू-"
#
# "पाणाम्"
#
# "[१."
#
# "२."
#
# "६४"
#
# "]"
#
# "इत्येकशेष"
#
# "आरम्यते"
#
# "॥"
#
# "किं"
#
# "पुनर्नित्यः"
#
# "शुब्द"
#
# "आहोस्वित्कार्यः"
#
# "|"
#
# "संग्रह"
#
# "एतत्पाधान्येन"
#
# "परीक्षितं"
#
# "नित्यो"
#
# "वा"
#
# "स्यात्कार्यों"
#
# "बेति"
#
# "|"
#
# "तत्रोक्ता"
#
# "दोषाः"
#
# "प्रयोजनान्यप्युक्तानि"
#
# "।"
#
# "तत्र"
#
# "त्वेष"
#
# "निर्णयो"
#
# "येव"
#
# "नित्यो"
#
# "s्यापि"
#
# "कार्य"
#
# "उभयथापि"
#
# "लक्षणं"
#
# "प्रवर्त्येमिति"
#
# "|"
#
# "|"
#
# "कथं"
#
# "पुनरिदं"
#
# "भगवतः"
#
# "15"
#
# "पाणिनेराचार्यस्य"
#
# "लक्षणं"
#
# "प्रवृत्तम्"
#
# "।"
#
# "सिद्धे"
#
# "शब्दार्थसंबन्धे"
#
# "सिद्धे"
#
# "शब्दे"
#
# "ऽर्थे"
#
# "संबन्धे"
#
# "चेति"
#
# "|"
#
# "अथ"
#
# "सिद्धशष्दस्य"
#
# "कः"
#
# "पदार्थ:"
#
# "|"
#
# "नित्यपर्यायवाची"
#
# "सिद्शब्दः"
#
# "|"
#
# "करथं"
#
# "ज्ञायते"
#
# "।"
#
# "यत्कूटस्थेष्वाविचालिषु"
#
# "भावेषु"
#
# "वतैते"
#
# "|"
#
# "त्था"
#
# "|"
#
# "सिद्धा"
#
# "यौः"
#
# "सिद्धा"
#
# "पृथिवी"
#
# "सिद्धमाकाशमिति"
#
# "|"
#
# "ननु"
#
# "च"
#
# "भौः"
#
# "कार्येष्वपि"
#
# "वर्तते"
#
# "|"
#
# "तद्यथा"
#
# "।"
#
# "20"
#
# "सिद्ध"
#
# "भदन:"
#
# "सिद्धः"
#
# "सूपः"
#
# "सिद्धा"
#
# "यवागूरिति"
#
# "।"
#
# "यावता"
#
# "कार्येष्वपि"
#
# "वर्तते"
#
# "तत्र"
#
# "कुत"
#
# "एतभित्यपर्यायवाचिनो"
#
# "ग्रहणं"
#
# "न"
#
# "पुनः"
#
# "कार्ये"
#
# "यः"
#
# "सिद्धशब्द"
#
# "हति"
#
# "|"
#
# "संग्रहे"
#
# "तावल्कार्य-"
#
# "प्रतिहन्दिभावान्मन्यामहे"
#
# "नित्यपर्यायवाचिनो"
#
# "ग्रहणमिति"
#
# "|"
#
# "इहापि"
#
# "तदैव"
#
# "||"
#
# "अथवा"
#
# "सन्त्येकपदान्यप्यवधारणानि"
#
# "|"
#
# "तद्यथाब्भक्षो"
#
# "वायुभक्ष"
#
# "इत्यप"
#
# "एव"
#
# "भक्षयति"
#
# "वायुमेव"
#
# "25"
#
# "भक्षयतीति"
#
# "गम्यत"
#
# "एवमिहापि"
#
# "सिद्ध"
#
# "एव"
#
# "न"
#
# "साध्य"
#
# "इति"
#
# "॥"
#
# "अथवा"
#
# "पूर्वपदलोपो"
#
# "sत्र"
#
# "दष्टव्यः"
#
# "।"
#
# "अल्यन्तसिद्धः"
#
# "सिद्ध"
#
# "इति"
#
# "|"
#
# "तथ्यथा"
#
# "।"
#
# "देवदत्तो"
#
# "दत्तः"
#
# "सत्यभामा"
#
# "भामेति"
#
# "॥"
#
# "अथवा"
#
# "व्याख्यानतो"
#
# "विशेषमतिपत्तिर्न"
#
# "हि"
#
# "संदेहादलक्षणमिति"
#
# "नित्यपर्यायवाचिनो"
#
# "अ्रहणमिति"
#
# "व्याख्यास्यामः"
#
# "॥"
#
# "किं"
#
# "पुनरनेन"
#
# "वर्ण्येन"
#
# "किं"
#
# "न"
#
# "महता"
#
# "कण्डेन"
#
# "नित्यशभ्द"
#
# "यस्मिच्ुपादीयमाने"
#
# "ऽसंदेहः"
#
# "स्यात्"
#
# "।"
#
# "मङ्गलार्यम्"
#
# "।"
#
# "माङ्गलिक"
#
# "आचार्यों"
#
# "एवोपात्तो"
#
# "in"
# Texts:
#
# "म० १.१.१. ]
# "॥ व्याकरणमहाभाष्यम् ॥
# महतः शालौघस्य मङ्गलाये सिद्धशब्दमादितः प्रयुड्डे मङ्गलादीनि हि शाख्त्राणि प्रथन्ते
# वीरपुरुषकाणि च भवन्त्यायुष्मत्पुरुषकाणि चाध्येतार् सिद्धार्थी यथा स्युरिति ।
# अयं खल्वपि नित्यशभ्दो नावदयं कूटस्थेष्वविचालिषु भावेषु वर्ते | किं तर्हि |
# आभीक्ष्ये ऽपि वर्तेते | तव्यथा । नित्यप्रहसितो नित्यप्रजल्पित इति । यावताभी-
# क्षण्ये अपि वर्तैते तत्राप्यनेनैवार्थः स्याव्याख्यानतो विशेष्रतिपत्तिर्न हि संदेहादलक्षण- 5
# मिति | पश्यति स्वाचार्यौ मङ्गलार्थश्वैव सिद्धशम्द आदितः प्रयुक्तो भविष्यति शक्ष्यामि
# चैनं नित्यपर्यायवाचिनं वर्णयितुमिति | अतः सिद्धशब्द एवोपात्तो न नित्यशब्दः ||
# अथ क पुनः पदार्थ मर्वैष विप्रहः क्रियते सिद्धे शब्दे अ्ये संबन्धे चेति | आकृধ-
# तिमित्याह | कुत एतत् | आकृतिहि नित्या द्रव्यमनित्यम् ॥ अथ द्रव्ये पदार्थे कथं
# विग्रह: कर्तव्यः । सिद्धे शब्दे ऽर्थसंबन्धे चेति | नित्यो द्यर्थवतामर्वैरभिसंबन्धः |॥| 10
# अथवा द्रव्य एव पदार्थे एष वि्रहो न्याय्यः सिद्धे शब्दे ऽ्ये संबन्धे चेति। इ्रव्यं
# हि नित्यमाकृतिरनित्या । करथं ज्ञायते । एवं हि वृश्यते लोके | मृत्कयाचिदाकृत्या
# युक्ता पिण्डो भवति | पिण्डाकृतिमुपमृ्य घटिकाः क्रियन्ते । घटिकाकृतिमुपमृष्य
# कुण्डिकाः क्रियन्ते | तथा सुवर्णै कयाचिदाकृत्या युक्तं पिण्डो भवति | पिण्डा -
# कृतिमुपमृद्य रुचकाः क्रियन्ते | रुचकाकृतिमुपमृ् कटकाः क्रियन्ते । कटकाकृक 15
# तिमुपमृशय स्वस्तिकाः क्रियन्ते । पुनरावृत्तः
# खदिराङ्गारसवर्णे कुण्डले भवतः | आकृतिरन्या चान्या च भवति द्रव्यं पुनर्तदेव |
# आकृत्युपमर्देन इ्रव्यमेवावशिष्यते ॥ आकृतावपि पदार्थ एष विभहो न्याय्यः सिद्े
# शम्दे जै संबन्धे चेति । ननु चोक्तमाकृतिराনित्येति । नैतदस्ति । नित्याकृति: |
# कथम् । न क्वचिदुपरतेति कृस्वा सर्वत्रोपरता भवति द्रव्यान्तरस्था तूपलभ्यते ।। 20
# अथवा नेदमेव नित्यलक्षणं ध्रुवं कूटस्थमविचाल्यनपायोपजनविकायेनुत्पत्त्यवृदख्ध -
# व्यवयोगि यत्तभित्यमिति । तदपि नित्यं यसमिस्तस्वं न विहन्यते । किं पुनर्त -
# सुवर्णपिण्डः पुनरपरयाकृत्या युक्तः
# I3D
# त्वम् । तङ्गावस्तत्वम् । आकृतावपि तत्त्वं न विहन्यते ।। अथवा किं न एतेनेदं
# नित्यमिदमनित्यमिति | यन्रित्यं तं पदार्थ मत्वैष विग्रह: क्रियते सिद्धे शब्दे रथ
# संबन्धे चेति |॥
# 25
# कथं पुनर्शीयते सिदधः शब्दो र्धेः संवन्धश्चेति | लोकतः | यल्लोके र्येमर्थमुपा-
# दाय शब्हान्ध्रयुष्जते नैषां निर्वृत्तौ यत्नं कुर्वन्ति | ये पुनः
# तावत्तेषां यत्रः क्रियते | तदयथा | घटेन कायैं करिष्यन्कुम्भकारकुलं गत्वाह कुरु
# परट कार्यमनेन करिष्यामीनि | न तद्दच्छब्दान्प्रयोक्ष्यमाणो वैयाकरणकुलं गत्वाह़
# कार्या भावा निर्वात्तौ
# "
#
# "म०"
#
# "१.१.१."
#
# "]"
#
# ""॥"
#
# "व्याकरणमहाभाष्यम्"
#
# "॥"
#
# "महतः"
#
# "शालौघस्य"
#
# "मङ्गलाये"
#
# "सिद्धशब्दमादितः"
#
# "प्रयुड्डे"
#
# "मङ्गलादीनि"
#
# "हि"
#
# "शाख्त्राणि"
#
# "प्रथन्ते"
#
# "वीरपुरुषकाणि"
#
# "च"
#
# "भवन्त्यायुष्मत्पुरुषकाणि"
#
# "चाध्येतार्"
#
# "सिद्धार्थी"
#
# "यथा"
#
# "स्युरिति"
#
# "।"
#
# "अयं"
#
# "खल्वपि"
#
# "नित्यशभ्दो"
#
# "नावदयं"
#
# "कूटस्थेष्वविचालिषु"
#
# "भावेषु"
#
# "वर्ते"
#
# "|"
#
# "किं"
#
# "तर्हि"
#
# "|"
#
# "आभीक्ष्ये"
#
# "ऽपि"
#
# "वर्तेते"
#
# "|"
#
# "तव्यथा"
#
# "।"
#
# "नित्यप्रहसितो"
#
# "नित्यप्रजल्पित"
#
# "इति"
#
# "।"
#
# "यावताभी-"
#
# "क्षण्ये"
#
# "अपि"
#
# "वर्तैते"
#
# "तत्राप्यनेनैवार्थः"
#
# "स्याव्याख्यानतो"
#
# "विशेष्रतिपत्तिर्न"
#
# "हि"
#
# "संदेहादलक्षण-"
#
# "5"
#
# "मिति"
#
# "|"
#
# "पश्यति"
#
# "स्वाचार्यौ"
#
# "मङ्गलार्थश्वैव"
#
# "सिद्धशम्द"
#
# "आदितः"
#
# "प्रयुक्तो"
#
# "भविष्यति"
#
# "शक्ष्यामि"
#
# "चैनं"
#
# "नित्यपर्यायवाचिनं"
#
# "वर्णयितुमिति"
#
# "|"
#
# "अतः"
#
# "सिद्धशब्द"
#
# "एवोपात्तो"
#
# "न"
#
# "नित्यशब्दः"
#
# "||"
#
# "अथ"
#
# "क"
#
# "पुनः"
#
# "पदार्थ"
#
# "मर्वैष"
#
# "विप्रहः"
#
# "क्रियते"
#
# "सिद्धे"
#
# "शब्दे"
#
# "अ्ये"
#
# "संबन्धे"
#
# "चेति"
#
# "|"
#
# "आकृধ-"
#
# "तिमित्याह"
#
# "|"
#
# "कुत"
#
# "एतत्"
#
# "|"
#
# "आकृतिहि"
#
# "नित्या"
#
# "द्रव्यमनित्यम्"
#
# "॥"
#
# "अथ"
#
# "द्रव्ये"
#
# "पदार्थे"
#
# "कथं"
#
# "विग्रह:"
#
# "कर्तव्यः"
#
# "।"
#
# "सिद्धे"
#
# "शब्दे"
#
# "ऽर्थसंबन्धे"
#
# "चेति"
#
# "|"
#
# "नित्यो"
#
# "द्यर्थवतामर्वैरभिसंबन्धः"
#
# "|॥|"
#
# "10"
#
# "अथवा"
#
# "द्रव्य"
#
# "एव"
#
# "पदार्थे"
#
# "एष"
#
# "वि्रहो"
#
# "न्याय्यः"
#
# "सिद्धे"
#
# "शब्दे"
#
# "ऽ्ये"
#
# "संबन्धे"
#
# "चेति।"
#
# "इ्रव्यं"
#
# "हि"
#
# "नित्यमाकृतिरनित्या"
#
# "।"
#
# "करथं"
#
# "ज्ञायते"
#
# "।"
#
# "एवं"
#
# "हि"
#
# "वृश्यते"
#
# "लोके"
#
# "|"
#
# "मृत्कयाचिदाकृत्या"
#
# "युक्ता"
#
# "पिण्डो"
#
# "भवति"
#
# "|"
#
# "पिण्डाकृतिमुपमृ्य"
#
# "घटिकाः"
#
# "क्रियन्ते"
#
# "।"
#
# "घटिकाकृतिमुपमृष्य"
#
# "कुण्डिकाः"
#
# "क्रियन्ते"
#
# "|"
#
# "तथा"
#
# "सुवर्णै"
#
# "कयाचिदाकृत्या"
#
# "युक्तं"
#
# "पिण्डो"
#
# "भवति"
#
# "|"
#
# "पिण्डा"
#
# "-"
#
# "कृतिमुपमृद्य"
#
# "रुचकाः"
#
# "क्रियन्ते"
#
# "|"
#
# "रुचकाकृतिमुपमृ्"
#
# "कटकाः"
#
# "क्रियन्ते"
#
# "।"
#
# "कटकाकृक"
#
# "15"
#
# "तिमुपमृशय"
#
# "स्वस्तिकाः"
#
# "क्रियन्ते"
#
# "।"
#
# "पुनरावृत्तः"
#
# "खदिराङ्गारसवर्णे"
#
# "कुण्डले"
#
# "भवतः"
#
# "|"
#
# "आकृतिरन्या"
#
# "चान्या"
#
# "च"
#
# "भवति"
#
# "द्रव्यं"
#
# "पुनर्तदेव"
#
# "|"
#
# "आकृत्युपमर्देन"
#
# "इ्रव्यमेवावशिष्यते"
#
# "॥"
#
# "आकृतावपि"
#
# "पदार्थ"
#
# "एष"
#
# "विभहो"
#
# "न्याय्यः"
#
# "सिद्े"
#
# "शम्दे"
#
# "जै"
#
# "संबन्धे"
#
# "चेति"
#
# "।"
#
# "ननु"
#
# "चोक्तमाकृतिराনित्येति"
#
# "।"
#
# "नैतदस्ति"
#
# "।"
#
# "नित्याकृति:"
#
# "|"
#
# "कथम्"
#
# "।"
#
# "न"
#
# "क्वचिदुपरतेति"
#
# "कृस्वा"
#
# "सर्वत्रोपरता"
#
# "भवति"
#
# "द्रव्यान्तरस्था"
#
# "तूपलभ्यते"
#
# "।।"
#
# "20"
#
# "अथवा"
#
# "नेदमेव"
#
# "नित्यलक्षणं"
#
# "ध्रुवं"
#
# "कूटस्थमविचाल्यनपायोपजनविकायेनुत्पत्त्यवृदख्ध"
#
# "-"
#
# "व्यवयोगि"
#
# "यत्तभित्यमिति"
#
# "।"
#
# "तदपि"
#
# "नित्यं"
#
# "यसमिस्तस्वं"
#
# "न"
#
# "विहन्यते"
#
# "।"
#
# "किं"
#
# "पुनर्त"
#
# "-"
#
# "सुवर्णपिण्डः"
#
# "पुनरपरयाकृत्या"
#
# "युक्तः"
#
# "I3D"
#
# "त्वम्"
#
# "।"
#
# "तङ्गावस्तत्वम्"
#
# "।"
#
# "आकृतावपि"
#
# "तत्त्वं"
#
# "न"
#
# "विहन्यते"
#
# "।।"
#
# "अथवा"
#
# "किं"
#
# "न"
#
# "एतेनेदं"
#
# "नित्यमिदमनित्यमिति"
#
# "|"
#
# "यन्रित्यं"
#
# "तं"
#
# "पदार्थ"
#
# "मत्वैष"
#
# "विग्रह:"
#
# "क्रियते"
#
# "सिद्धे"
#
# "शब्दे"
#
# "रथ"
#
# "संबन्धे"
#
# "चेति"
#
# "|॥"
#
# "25"
#
# "कथं"
#
# "पुनर्शीयते"
#
# "सिदधः"
#
# "शब्दो"
#
# "र्धेः"
#
# "संवन्धश्चेति"
#
# "|"
#
# "लोकतः"
#
# "|"
#
# "यल्लोके"
#
# "र्येमर्थमुपा-"
#
# "दाय"
#
# "शब्हान्ध्रयुष्जते"
#
# "नैषां"
#
# "निर्वृत्तौ"
#
# "यत्नं"
#
# "कुर्वन्ति"
#
# "|"
#
# "ये"
#
# "पुनः"
#
# "तावत्तेषां"
#
# "यत्रः"
#
# "क्रियते"
#
# "|"
#
# "तदयथा"
#
# "|"
#
# "घटेन"
#
# "कायैं"
#
# "करिष्यन्कुम्भकारकुलं"
#
# "गत्वाह"
#
# "कुरु"
#
# "परट"
#
# "कार्यमनेन"
#
# "करिष्यामीनि"
#
# "|"
#
# "न"
#
# "तद्दच्छब्दान्प्रयोक्ष्यमाणो"
#
# "वैयाकरणकुलं"
#
# "गत्वाह़"
#
# "कार्या"
#
# "भावा"
#
# "निर्वात्तौ"
# Texts:
#
# "अथैतस्मिञ्शम्दोपदेशे सति किं शब्दानां प्रतिपत्तौ प्रतिपदपाठ: कर्तव्यः ।
# गौरश्चः पुरुषो हस्ती शकुनिर्मृगो ब्राह्मण इत्येवमादयः शब्दाः पठितव्याः । नेस्याह ।
# भनभ्युषाय एष शब्हानां प्रतिपत्तौ प्रतिपदपाठः । एवं हि भूरूयते । बृहस्पतिरिन्द्राय 25
# दिव्यं वर्षसहसं प्रतिपदोक्तानां शब्दानां शब्दपारायणं प्रोवाच नान्तं जगाम | बृह-
# स्पतिथच प्रव्तेन्द्र्ाध्येता दिव्य वर्षसहस्र्रमध्ययनकालो न चान्तं जगाम । किं
# पुनरचत्ये यः सर्वथा चिरं जीवति स वर्षशरतं जीबति चतुर्भिच प्रकारेश्विद्योपयुक्का
# 25
# "
#
# "अथैतस्मिञ्शम्दोपदेशे"
#
# "सति"
#
# "किं"
#
# "शब्दानां"
#
# "प्रतिपत्तौ"
#
# "प्रतिपदपाठ:"
#
# "कर्तव्यः"
#
# "।"
#
# "गौरश्चः"
#
# "पुरुषो"
#
# "हस्ती"
#
# "शकुनिर्मृगो"
#
# "ब्राह्मण"
#
# "इत्येवमादयः"
#
# "शब्दाः"
#
# "पठितव्याः"
#
# "।"
#
# "नेस्याह"
#
# "।"
#
# "भनभ्युषाय"
#
# "एष"
#
# "शब्हानां"
#
# "प्रतिपत्तौ"
#
# "प्रतिपदपाठः"
#
# "।"
#
# "एवं"
#
# "हि"
#
# "भूरूयते"
#
# "।"
#
# "बृहस्पतिरिन्द्राय"
#
# "25"
#
# "दिव्यं"
#
# "वर्षसहसं"
#
# "प्रतिपदोक्तानां"
#
# "शब्दानां"
#
# "शब्दपारायणं"
#
# "प्रोवाच"
#
# "नान्तं"
#
# "जगाम"
#
# "|"
#
# "बृह-"
#
# "स्पतिथच"
#
# "प्रव्तेन्द्र्ाध्येता"
#
# "दिव्य"
#
# "वर्षसहस्र्रमध्ययनकालो"
#
# "न"
#
# "चान्तं"
#
# "जगाम"
#
# "।"
#
# "किं"
#
# "पुनरचत्ये"
#
# "यः"
#
# "सर्वथा"
#
# "चिरं"
#
# "जीवति"
#
# "स"
#
# "वर्षशरतं"
#
# "जीबति"
#
# "चतुर्भिच"
#
# "प्रकारेश्विद्योपयुक्का"
#
# "25"
